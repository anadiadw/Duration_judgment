# %%
## importing all libraries and dependencies
import pandas as pd
import numpy as np
import os
from os import listdir
import glob
from os.path import isfile, join
import shutil
import PIL
from PIL import Image
import random
from random import sample
import math
from heapq import merge
from random import *
import secrets
from scipy.stats import spearmanr
from scipy import stats
import matplotlib.pyplot as plt

# %%
pt_files = []
tst_ls = []
data_dir = '/Users/ayesh/Desktop/Gradstuff/duration_judgement/mTurk_OGdata/emobdr_data/actual_raw/worth/'
pt_files_ls = [f for f in listdir(data_dir)]
for c in pt_files_ls:
    if c[-3:] == 'csv':
        pt_files.append(c)

# %%
#1,Spearman rank correlation btwn actual duration of trial and the participants resp
### should be positive-- check!!!


#3 permutation test for each participant: over 10,000 iteration
### each participant's full distribution of resp shuffled, 
### rank correlation btwn time of each trial and shuffled resp computed
### Significance higher than 95% of this null distribution
allz = []
conds_diff = []
c_len = []
b_len = []
a_len = []
t_len = []
pt_c = []
pt_b = []
pt_resp = []
pt_cond = []
sub = []
true_tp = []
pt_throwout = []

tst_ls =[]
one_ls =[]
rho_ls =[]
zscr_ls =[]
cond_ls =[]
tp_ls =[]
resp_ls =[]
resp_diff_ls = []

for one in pt_files:
    pto = pd.read_csv(data_dir+one, header =0)
    pto.columns = pto.columns.str.replace(".", "_")
    sub_num = one.split('_', 1)[0]
    pt1 = pto[24:-1]
    pt = pt1[pt1['slider_response'].notna()]
    tp = pt.dur
    cond = pt.condition
    resp = pt.slider_response
    rho, p = spearmanr(tp, resp)
    zscr = np.arctanh(rho)
    pt["rho"] = rho
    pt["p_value"] = p
    pt["zscr"] = zscr
    allz.append(zscr)
    sub.append(sub_num)
    #for index, row in pt.iterrows():
     #   pt_resp.append(pt.slider_response[index])
      #  pt_cond.append(pt.condition[index])
       # true_tp.append(pt.dur[index])
    
    diff = [a - b for a, b in zip(tp, resp)]
    
    #c_len.append(continious)
    #b_len.append(boundary)
    a_len.append(pt_resp)
    t_len.append(true_tp)
    pt["resp_diff"] = (diff)
    #pt["pt_condition"] = pt_cond
    #pt["true_tp"] = true_tp
    #pt["pt_resp"] = pt_resp
    tst = [one, rho, zscr, cond, tp, resp]#np.mean(diff), continious, boundary] # add pt.slider_response for checking the below comparison with null dist
    tst_ls.append(tst)
    one_ls.append(one)
    rho_ls.append(rho)
    zscr_ls.append(zscr)
    cond_ls.append(cond)
    tp_ls.append(tp)
    resp_ls.append(resp)
    resp_diff_ls.append(diff)
    pt.to_csv('/Users/ayesh/Desktop/Gradstuff/duration_judgement/summary/mturk_summary/emobdr_summaries/' + sub_num + '.csv')
# Out:
# <ipython-input-3-78acd8be6801>:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pt["rho"] = rho
# <ipython-input-3-78acd8be6801>:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pt["p_value"] = p
# <ipython-input-3-78acd8be6801>:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pt["zscr"] = zscr
# <ipython-input-3-78acd8be6801>:59: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pt["resp_diff"] = (diff)

# %%
summary_dir = '/Users/ayesh/Desktop/Gradstuff/duration_judgement/summary/mturk_summary/emobdr_summaries/'
summary_files = [f for f in listdir(summary_dir)]
#cnct_summarydf = pd.DataFrame(columns = ['participant', 'dur', 'condition', 'slider_response', 'rho', 'p_value', 'zscr', 'resp_diff'])
pts = []
perceptual = []
both_switches = []
catch = []
percept_mean = []
pval_mean = []
ctch_mean = []
for a in summary_files:
    p_trials = []
    v_trials = []
    ctch_trials = []
    m_percept = []
    m_pval = []
    m_ctch = []
    onept = pd.read_csv(summary_dir + a)
    for index, row in onept.iterrows():
        if onept.switch[index] == "percept":
            p_trials.append(onept.resp_diff[index])
            m_percept.append(onept.slider_response[index])
        if onept.switch[index] == "per_val":
            v_trials.append(onept.resp_diff[index])
            m_pval.append(onept.slider_response[index])
        if onept.switch[index] == "catch":
            ctch_trials.append(onept.resp_diff[index])
            m_ctch.append(onept.slider_response[index])
    p_trials = [p_trials for p_trials in p_trials if str(p_trials) != 'nan']
    v_trials = [v_trials for v_trials in v_trials if str(v_trials) != 'nan']
    ctch_trials = [ctch_trials for ctch_trials in ctch_trials if str(ctch_trials) != 'nan']
    
    m_percept = [m_percept for m_percept in m_percept if str(m_percept) != 'nan']
    m_pval = [m_pval for m_pval in m_pval if str(m_pval) != 'nan']
    m_ctch = [m_ctch for m_ctch in m_ctch if str(m_ctch) != 'nan']
    
    pts.append(a)
    perceptual.append(np.mean(p_trials))
    both_switches.append(np.mean(v_trials))
    catch.append(np.mean(ctch_trials))
    
    percept_mean.append(np.mean(m_percept))
    pval_mean.append(np.mean(m_pval))
    ctch_mean.append(np.mean(m_ctch))
        #onept.participant.astype(str)
        
        #shrt_pt = onept[["participant", 'dur', 'condition', 'slider_response', 'rho', 'p_value', 'zscr', 'resp_diff']]

# %%
perceptual
# Out:
# [0.5783985209649123,
#  1.0970114943103448,
#  0.1982786770169492,
#  -0.3863579443392857,
#  0.7095800721754385,
#  -0.48083333331666667,
#  1.3550682261228069,
#  0.389176206137931,
#  0.40131822140677964,
#  0.6255116958947369,
#  0.47419065236842106,
#  0.5457699280175439,
#  1.0673706896551725,
#  0.44629629631578943,
#  0.6590155944561403,
#  1.430076628310345,
#  0.5185057470689656,
#  0.7314967105263158,
#  0.9982108908135592,
#  1.254555084694915,
#  1.0626915708448277,
#  0.5771666081,
#  0.5421295588999998,
#  0.4748538011929824,
#  0.6003411306140353,
#  -0.06125478927586209,
#  1.0348927550701754,
#  0.3313056997931034,
#  0.7677367260666668,
#  0.5102621822033898,
#  0.023305084779660996,
#  0.26507389163793105,
#  0.3517720306724137,
#  1.2365496935438598,
#  0.35203394396551724,
#  0.35470545974137935,
#  0.6406923662711863,
#  0.36187739463793095,
#  0.661530172362069,
#  0.6206896551724138,
#  0.1137433095423729,
#  0.8302356478620689,
#  0.8015517241379311,
#  1.200616934661017,
#  0.6278265108245613,
#  0.6345762712033898,
#  0.8998634309310345,
#  0.30034482762068965,
#  0.6903954802542374,
#  0.16630952376785718,
#  1.0863505506206896,
#  1.0996116690677968,
#  0.924901583338983,
#  0.540960294440678,
#  0.9607421875,
#  0.6815133844310343,
#  0.5495949884482758,
#  0.6877895402711866,
#  0.36179337229824565,
#  0.4095734126607143,
#  -0.08001077586206896,
#  0.4452241715789473,
#  0.7000782559473685,
#  0.5790330150877192,
#  0.478892219220339,
#  1.4935579610517242,
#  0.3919539908448276,
#  1.1805068010701754,
#  0.6974137930172414,
#  0.5169020715254237,
#  0.48044590654385966,
#  0.8710248717586208,
#  0.7198862511525423,
#  0.6886973180344829,
#  0.3485272479137932,
#  1.2482641770338982,
#  0.9235867446315789,
#  0.654449106,
#  0.18299220278947367,
#  1.0970603813559323,
#  1.6486659763389833,
#  0.6892022963965517,
#  1.0351489054067797,
#  0.4552842753050848,
#  0.2863520488392857,
#  1.466081855333333,
#  1.347060428016949,
#  0.5776315358070174,
#  0.34877189287719296,
#  0.9230263157894736,
#  0.4415708812586207,
#  0.05598659001724142,
#  0.9825249160862068,
#  0.30388884110344827,
#  0.9169020715423727,
#  0.5049137937678572,
#  0.9626212284482759,
#  0.4912534215964912,
#  0.5791015625,
#  0.9671052526842104,
#  1.3030214424736841,
#  0.6270551313157894,
#  0.6134159482758621,
#  -0.4808333333166666]

# %%
f_df = pd.DataFrame({"participants":pts,
                    "perceptual": perceptual,
                    "both_switches":both_switches,
                    "catch":catch,
                    "percept_mean": percept_mean,
                    "pval_mean": pval_mean,
                    "ctch_mean": ctch_mean})
f_df.to_csv('/Users/ayesh/Desktop/Gradstuff/duration_judgement/summary/mturk_summary/emobdr_conddurs_r.csv')

# %% [markdown]
# ## group check if correlation significant

# %%
#combine all files in the list
combined_csv = pd.concat([pd.read_csv(summary_dir + f) for f in summary_files])
#export to csv
combined_csv.to_csv('/Users/ayesh/Desktop/Gradstuff/duration_judgement/summary/mturk_summary/emobdr_combined_csv.csv', index=False, encoding='utf-8-sig')
to_cln = pd.read_csv('/Users/ayesh/Desktop/Gradstuff/duration_judgement/summary/mturk_summary/emobdr_combined_csv.csv') #, index=False, encoding='utf-8-sig')
to_cln
clnd_combined = to_cln[to_cln["rho"]>=0.75]
exclude = to_cln[to_cln["rho"]<0.75]
clnd_combined.to_csv('/Users/ayesh/Desktop/Gradstuff/duration_judgement/summary/mturk_summary/emobdr_combined_csv.csv', index=False, encoding='utf-8-sig')

# %%
print(len(clnd_combined.participant.unique()))
clnd_combined.participant.unique()
print(len(exclude.participant.unique()))
exclude.participant.unique()
# Out:
# 39
# 65
# array(['1nan', '2nan', '4nan', '5nan', '6nan', 'A100VV1V2XDQI7',
#        'A19CB2C4GY4C60', 'A1A1A9UHNQCI9Y', 'A1C57DJF1HCR3Q',
#        'A1DZLZE63NE1ZI', 'A1GKEEI844CEKI', 'A1H5BQHY7VOY3I',
#        'A1HWI4N1RJGKYY', 'A1IIUECI2HNG55', 'A1MTRZDRKNB9GV',
#        'A1NHTBY5YB9JH7', 'A1PJLZSOUQ4MIL', 'A1SWRO4LMKPCOQ',
#        'A1WGSW0SLN4Y91', 'A26L91YL0GDGD8', 'A26ZENZ5G8AEGM',
#        'A27PVIL93ZMY46', 'A28Q19NTTP0UIQ', 'A2AVFNOKFHQ2ME',
#        'A2B338ZP97RA5W', 'A2F0X4LN9N4O4C', 'A2GM5BW75YCKKW',
#        'A2IOT3PCS9G5RK', 'A2OJ5XOEKTKRR9', 'A2U31V169A20GY',
#        'A2W547SNOCMC25', 'A2WMSIPUKEIBNS', 'A2YLF04UAKYVF1',
#        'A314XJY8V1YL12', 'A36SM7QM8OK3H6', 'A37QFZ8I1TGH2C',
#        'A3BVPQFBYGWJWX', 'A3CFNUD7VR2E1E', 'A3DZ46U9XRLVBI',
#        'A3EVR7FOPM6EA0', 'A3FOKP72T5I4FR', 'A3GCA0EZKHTJME',
#        'A3L60SOWLYEDN2', 'A3MS21UJPMHLK0', 'A3NH3BCC6GHEWR',
#        'A3UJO2A7THUZTV', 'A5V3ZMQI0PU3F', 'A6PPB69C6ZJHN',
#        'A8FUMDQFBKMXR', 'A8KHWKKGAGOH0', 'ABOEYY9Y0PFRI', 'ACCXC5V05C9R9',
#        'ACVEFRSUAPSEQ', 'AELOYBHVZFDW9', 'AIPHJXQEDNW9L', 'AJY6J33X1KJNP',
#        'ALVNMQMD3Q3ZE', 'AMG9Y1YLBTKIV', 'AQAXDL1INQC9Q', 'AU2NVT51E749C',
#        'AVOF14300525D', 'AVQGY7FCU80XP', 'AXOR2N1EAFVYF', 'AYJGQBBK6KXZ7',
#        'pilot'], dtype=object)

# %%
exlst = []
e_lst = exclude.participant.unique()
for a in e_lst:
    csv = a + '.csv'
    exlst.append(csv)
exlst
# Out:
# ['1nan.csv',
#  '2nan.csv',
#  '4nan.csv',
#  '5nan.csv',
#  '6nan.csv',
#  'A100VV1V2XDQI7.csv',
#  'A19CB2C4GY4C60.csv',
#  'A1A1A9UHNQCI9Y.csv',
#  'A1C57DJF1HCR3Q.csv',
#  'A1DZLZE63NE1ZI.csv',
#  'A1GKEEI844CEKI.csv',
#  'A1H5BQHY7VOY3I.csv',
#  'A1HWI4N1RJGKYY.csv',
#  'A1IIUECI2HNG55.csv',
#  'A1MTRZDRKNB9GV.csv',
#  'A1NHTBY5YB9JH7.csv',
#  'A1PJLZSOUQ4MIL.csv',
#  'A1SWRO4LMKPCOQ.csv',
#  'A1WGSW0SLN4Y91.csv',
#  'A26L91YL0GDGD8.csv',
#  'A26ZENZ5G8AEGM.csv',
#  'A27PVIL93ZMY46.csv',
#  'A28Q19NTTP0UIQ.csv',
#  'A2AVFNOKFHQ2ME.csv',
#  'A2B338ZP97RA5W.csv',
#  'A2F0X4LN9N4O4C.csv',
#  'A2GM5BW75YCKKW.csv',
#  'A2IOT3PCS9G5RK.csv',
#  'A2OJ5XOEKTKRR9.csv',
#  'A2U31V169A20GY.csv',
#  'A2W547SNOCMC25.csv',
#  'A2WMSIPUKEIBNS.csv',
#  'A2YLF04UAKYVF1.csv',
#  'A314XJY8V1YL12.csv',
#  'A36SM7QM8OK3H6.csv',
#  'A37QFZ8I1TGH2C.csv',
#  'A3BVPQFBYGWJWX.csv',
#  'A3CFNUD7VR2E1E.csv',
#  'A3DZ46U9XRLVBI.csv',
#  'A3EVR7FOPM6EA0.csv',
#  'A3FOKP72T5I4FR.csv',
#  'A3GCA0EZKHTJME.csv',
#  'A3L60SOWLYEDN2.csv',
#  'A3MS21UJPMHLK0.csv',
#  'A3NH3BCC6GHEWR.csv',
#  'A3UJO2A7THUZTV.csv',
#  'A5V3ZMQI0PU3F.csv',
#  'A6PPB69C6ZJHN.csv',
#  'A8FUMDQFBKMXR.csv',
#  'A8KHWKKGAGOH0.csv',
#  'ABOEYY9Y0PFRI.csv',
#  'ACCXC5V05C9R9.csv',
#  'ACVEFRSUAPSEQ.csv',
#  'AELOYBHVZFDW9.csv',
#  'AIPHJXQEDNW9L.csv',
#  'AJY6J33X1KJNP.csv',
#  'ALVNMQMD3Q3ZE.csv',
#  'AMG9Y1YLBTKIV.csv',
#  'AQAXDL1INQC9Q.csv',
#  'AU2NVT51E749C.csv',
#  'AVOF14300525D.csv',
#  'AVQGY7FCU80XP.csv',
#  'AXOR2N1EAFVYF.csv',
#  'AYJGQBBK6KXZ7.csv',
#  'pilot.csv']

# %% [markdown]
# ## graph

# %%
grph_csv = pd.read_csv('/Users/ayesh/Desktop/Gradstuff/duration_judgement/summary/mturk_summary/emobdr_conddurs_r.csv')
grph_csv["abs_perceptual"] = abs(grph_csv.perceptual)
grph_csv["abs_bothswitches"] = abs(grph_csv.both_switches)
grph_csv = grph_csv[~grph_csv['participants'].isin(exlst)]
grph_csv.to_csv('/Users/ayesh/Desktop/Gradstuff/duration_judgement/summary/mturk_summary/emobdr_conddurs_r.csv')
grph_csv
# Out:
#      Unnamed: 0        participants  perceptual  both_switches     catch  \
# 2             2            3nan.csv    0.198279       0.180455  0.035675
# 7             7  A10TYO0H3GLCH6.csv    0.389176       0.319732  0.372338
# 8             8  A14PFRHG0A2YY9.csv    0.401318       0.340984  0.465509
# 11           11  A1BHINLXH3E2GJ.csv    0.545770       0.530948  0.886940
# 13           13  A1C59M3HPCO503.csv    0.446296       0.403202  0.506481
# 14           14  A1D4I1QYL9713I.csv    0.659016       0.669209  0.774306
# 16           16  A1FGKIKJYSL1MI.csv    0.518506       0.421379  0.976667
# 21           21  A1M1TSMJB12177.csv    0.577167       0.519583  0.469167
# 24           24  A1NIO3JNX5QTN8.csv    0.600341       0.523164  0.107407
# 27           27  A1UKZZL7ANOZRZ.csv    0.331306       0.341474  0.426719
# 29           29  A1XAOEDK0Y2KBT.csv    0.510262       0.548693  0.784091
# 30           30   A1Y25W1Y7KDE5.csv    0.023305       0.003314  0.084954
# 31           31  A20HZD952T4B2O.csv    0.265074       0.301921  0.253571
# 36           36  A2AAY4VT9L71SY.csv    0.640692       0.668467  0.702557
# 40           40  A2FCGEU5RTEWG8.csv    0.113743       0.071488  0.110231
# 42           42  A2HM35CWB7IIFM.csv    0.801552       0.831322  0.947222
# 45           45  A2PEXE95UD6Y5S.csv    0.634576       0.836264  1.165758
# 46           46  A2R2YZTSME1K3F.csv    0.899863       0.898077  0.585645
# 47           47  A2SBN9B6Q3DN2X.csv    0.300345       0.288333  0.293611
# 49           49  A2VE5IV9OD2SK1.csv    0.166310       0.211500  0.447778
# 51           51  A2WCCV1W8UE8ED.csv    1.099612       1.109075  1.243156
# 53           53  A2WNW8A4MOR7T7.csv    0.540960       0.534941  0.513426
# 56           56  A31Z5TPD8QKE26.csv    0.549595       0.475889  0.236736
# 57           57  A32UE0WDFAUWBE.csv    0.687790       0.671912  0.617503
# 58           58  A35BY30TC8WCL4.csv    0.361793       0.262006  0.310417
# 63           63  A3CVY8G619MGTI.csv    0.579033       0.620785  0.587628
# 68           68  A3GNQDFPZALU92.csv    0.697414       0.840207  0.511616
# 69           69  A3JZS32RQUWGJM.csv    0.516902       0.538840  0.435417
# 73           73  A3O2JUIF4DZQJU.csv    0.688697       0.716379  0.455556
# 74           74  A3QC57KUVJP5EW.csv    0.348527       0.383118  0.168924
# 76           76  A3V9JFVZQ2XF4Y.csv    0.923587       1.054954  0.737626
# 77           77   A4SC8G0149GEG.csv    0.654449       0.704825  0.662674
# 78           78   A4W9APAHFWVLO.csv    0.182992       0.185546  0.168981
# 79           79   A5TI9UQEPLNWI.csv    1.097060       1.040913  0.820312
# 84           84   A9WIOFVRSYW3L.csv    0.286352       0.292619  0.317474
# 91           91   AKX5RHHO8BIUX.csv    0.055987      -0.019444  0.196528
# 94           94   AML72HK5V5OP0.csv    0.916902       0.887963  1.000463
# 96           96   ATHS9GUME1XCA.csv    0.962621       0.870353  1.081706
# 102         102             bdr.csv    0.613416       0.668710  0.846029
#
#      percept_mean  pval_mean  ctch_mean  abs_perceptual  abs_bothswitches
# 2        3.564433   3.560924   3.418870        0.198279          0.180455
# 7        3.343582   3.447510   3.127662        0.389176          0.319732
# 8        3.344444   3.395858   3.117824        0.401318          0.340984
# 11       3.217388   3.223289   2.696394        0.545770          0.530948
# 13       3.360721   3.359510   2.993519        0.446296          0.403202
# 14       3.086598   3.076554   2.725694        0.659016          0.669209
# 16       3.231494   3.311379   2.648333        0.518506          0.421379
# 21       3.172833   3.257202   3.072500        0.577167          0.519583
# 24       3.154045   3.214124   3.350926        0.600341          0.523164
# 27       3.401453   3.429712   2.936917        0.331306          0.341474
# 29       3.227026   3.227169   2.715909        0.510262          0.548693
# 30       3.722458   3.768616   3.415046        0.023305          0.003314
# 31       3.510788   3.482562   3.288095        0.265074          0.301921
# 36       3.088121   3.077147   2.672443        0.640692          0.668467
# 40       3.640494   3.682898   3.389769        0.113743          0.071488
# 42       2.957069   2.910057   2.552778        0.801552          0.831322
# 45       3.111186   2.922356   2.197879        0.634576          0.836264
# 46       2.875999   2.869164   2.956021        0.899863          0.898077
# 47       3.423793   3.444425   3.164722        0.300345          0.288333
# 49       3.565833   3.538500   3.052222        0.166310          0.211500
# 51       2.629202   2.671627   2.298511        1.099612          1.109075
# 53       3.230226   3.236988   3.069908        0.540960          0.534941
# 56       3.165922   3.248249   3.346597        0.549595          0.475889
# 57       3.083397   3.078088   2.700679        0.687790          0.671912
# 58       3.366277   3.509181   3.106250        0.361793          0.262006
# 63       3.166581   3.133452   2.912372        0.579033          0.620785
# 68       3.052586   2.930979   3.033838        0.697414          0.840207
# 69       3.245810   3.180458   3.022917        0.516902          0.538840
# 73       3.069923   3.059483   2.961111        0.688697          0.716379
# 74       3.410093   3.384124   3.372743        0.348527          0.383118
# 76       2.778168   2.695046   2.716919        0.923587          1.054954
# 77       3.108263   3.067105   2.795660        0.654449          0.704825
# 78       3.562622   3.577166   3.331019        0.182992          0.185546
# 79       2.657177   2.695929   2.721354        1.097060          1.040913
# 84       3.463648   3.457381   3.140859        0.286352          0.292619
# 91       3.694013   3.786686   3.178472        0.055987          0.019444
# 94       2.828861   2.875195   2.541204        0.916902          0.887963
# 96       2.795999   2.879647   2.376628        0.962621          0.870353
# 102      3.127963   3.115773   2.737305        0.613416          0.668710

# %%
mediumseagreen = '#FFB6C1'
cyan = '#DA70D6'
totalpts = len(grph_csv)
fig, ax = plt.subplots(figsize=(5, 6))

##################
#BAR GRAPHS
##################
## necessary variables
ind = np.arange(1) # the x locations for the groups
width = 0.35 # the width of the bars
#source-corrected bias bars
ax.bar(ind, np.mean(grph_csv.perceptual), width,
    color= mediumseagreen,
    #hatch = '.',
    edgecolor= mediumseagreen,
    alpha = 0.5,
    yerr=stats.sem(grph_csv.perceptual),
    label = "Safe",
    error_kw=dict(elinewidth=2,ecolor= "black"))
ax.bar(ind+width,np.mean(grph_csv.both_switches)  , width,
    color= cyan,
    #hatch = '.',
    edgecolor= cyan,
    alpha = 0.8,
    yerr=stats.sem(grph_csv.both_switches),
    label = "Threat",
    error_kw=dict(elinewidth=2,ecolor= "black"))

#ax.legend()

##################
#SCATTERPLOT GRAPHS
##################
exps2 = []
#i = 1.0
i = 0.2

     # Get the values for same_context and bound_context bias in each valence condition
h = grph_csv.perceptual
d = grph_csv.both_switches
     # Set up the x-axis values
x1 = i - 0.2
x2 = i + 0.2
line_color = ["black"]
line_colors = np.repeat(line_color, len(d))
alphas = [0.5]*len(line_colors)

     # Plot the lines connecting the dots
for hi, di, ci, ai in zip(h, d, line_colors, alphas):
    ax.plot([x1 + 0.03, x2 - 0.08], [hi, di], c=ci, alpha=ai, linewidth = 1)

        # Plot the points
        # Note: s=25 increase the default point size, lw=0.5 decreases the default point line width
ax.scatter(len(h)*[x1+0.03], h, c=mediumseagreen, edgecolors= "black",
s=25, lw=0.5, zorder=10)
ax.scatter(len(d)*[x2-0.08], d, c=cyan, edgecolors= "black",
s=25, lw=0.5, zorder=10)
#ax.legend(loc = 'lower left', fontsize = "large")

# Fix the axes and labels 
#legend_elements = []
plt.ylim(-2, 2)
plt.xlabel("Perceptual               Percept_val", fontsize = "x-large")
plt.ylabel("True time- perceived time", fontsize = "x-large")
plt.yticks(fontsize = "x-large")
plt.axhline(y = 0.0, color = 'k', linestyle = '-')
plt.title("All participants (N = %s) duration bias"%totalpts, fontsize = "x-large")
#plt.legend(handles=legend_elements, loc='center')
ax.xaxis.set_tick_params(labelbottom=False)
ax.set_xticks([])
# Out:
# []

# %%
mediumseagreen = '#FFB6C1' #pink
cyan = '#DA70D6' #orchid
totalpts = len(grph_csv)
fig, ax = plt.subplots(figsize=(5, 6))

##################
#BAR GRAPHS
##################
## necessary variables
ind = np.arange(1) # the x locations for the groups
width = 0.35 # the width of the bars
#source-corrected bias bars
ax.bar(ind, np.mean(grph_csv.cont_mean), width,
    color= mediumseagreen,
    #hatch = '.',
    edgecolor= mediumseagreen,
    alpha = 0.5,
    yerr=stats.sem(grph_csv.cont_mean),
    label = "Safe",
    error_kw=dict(elinewidth=2,ecolor= "black"))
ax.bar(ind+width,np.mean(grph_csv.bdry_mean)  , width,
    color= cyan,
    #hatch = '.',
    edgecolor= cyan,
    alpha = 0.8,
    yerr=stats.sem(grph_csv.bdry_mean),
    label = "Threat",
    error_kw=dict(elinewidth=2,ecolor= "black"))

#ax.legend()

##################
#SCATTERPLOT GRAPHS
##################
exps2 = []
#i = 1.0
i = 0.2

     # Get the values for same_context and bound_context bias in each valence condition
h = grph_csv.cont_mean
d = grph_csv.bdry_mean
     # Set up the x-axis values
x1 = i - 0.2
x2 = i + 0.2
line_color = ["black"]
line_colors = np.repeat(line_color, len(d))
alphas = [0.5]*len(line_colors)

     # Plot the lines connecting the dots
for hi, di, ci, ai in zip(h, d, line_colors, alphas):
    ax.plot([x1 + 0.03, x2 - 0.08], [hi, di], c=ci, alpha=ai, linewidth = 1)

        # Plot the points
        # Note: s=25 increase the default point size, lw=0.5 decreases the default point line width
ax.scatter(len(h)*[x1+0.03], h, c=mediumseagreen, edgecolors= "black",
s=25, lw=0.5, zorder=10)
ax.scatter(len(d)*[x2-0.08], d, c=cyan, edgecolors= "black",
s=25, lw=0.5, zorder=10)
#ax.legend(loc = 'lower left', fontsize = "large")

# Fix the axes and labels 
#legend_elements = []
plt.ylim(0, 5)
plt.xlabel("Continious               Boundary", fontsize = "x-large")
plt.ylabel("Mean duration judgement (s)", fontsize = "x-large")
plt.yticks(fontsize = "x-large")
plt.axhline(y = 0.0, color = 'k', linestyle = '-')
plt.title("All participants (N = %s) duration bias"%totalpts, fontsize = "x-large")
#plt.legend(handles=legend_elements, loc='center')
ax.xaxis.set_tick_params(labelbottom=False)
ax.set_xticks([])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-5b288f5c7a71> in <module>
#      11 width = 0.35 # the width of the bars
#      12 #source-corrected bias bars
# ---> 13 ax.bar(ind, np.mean(grph_csv.cont_mean), width,
#      14     color= mediumseagreen,
#      15     #hatch = '.',
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'cont_mean'

# %%
mediumseagreen = '#FFB6C1' #pink
cyan = '#DA70D6' #orchid
totalpts = len(grph_csv)
fig, ax = plt.subplots(figsize=(5, 6))

##################
#BAR GRAPHS
##################
## necessary variables
ind = np.arange(1) # the x locations for the groups
width = 0.35 # the width of the bars
#source-corrected bias bars
ax.bar(ind, np.mean(grph_csv.abs_cont), width,
    color= mediumseagreen,
    #hatch = '.',
    edgecolor= mediumseagreen,
    alpha = 0.5,
    yerr=stats.sem(grph_csv.abs_cont),
    label = "Safe",
    error_kw=dict(elinewidth=2,ecolor= "black"))
ax.bar(ind+width,np.mean(grph_csv.abs_bdr)  , width,
    color= cyan,
    #hatch = '.',
    edgecolor= cyan,
    alpha = 0.8,
    yerr=stats.sem(grph_csv.abs_bdr),
    label = "Threat",
    error_kw=dict(elinewidth=2,ecolor= "black"))

#ax.legend()

##################
#SCATTERPLOT GRAPHS
##################
exps2 = []
#i = 1.0
i = 0.2

     # Get the values for same_context and bound_context bias in each valence condition
h = grph_csv.abs_cont
d = grph_csv.abs_bdr
     # Set up the x-axis values
x1 = i - 0.2
x2 = i + 0.2
line_color = ["black"]
line_colors = np.repeat(line_color, len(d))
alphas = [0.5]*len(line_colors)

     # Plot the lines connecting the dots
for hi, di, ci, ai in zip(h, d, line_colors, alphas):
    ax.plot([x1 + 0.03, x2 - 0.08], [hi, di], c=ci, alpha=ai, linewidth = 1)

        # Plot the points
        # Note: s=25 increase the default point size, lw=0.5 decreases the default point line width
ax.scatter(len(h)*[x1+0.03], h, c=mediumseagreen, edgecolors= "black",
s=25, lw=0.5, zorder=10)
ax.scatter(len(d)*[x2-0.08], d, c=cyan, edgecolors= "black",
s=25, lw=0.5, zorder=10)
#ax.legend(loc = 'lower left', fontsize = "large")

# Fix the axes and labels 
#legend_elements = []
plt.ylim(0, 2)
plt.xlabel("Continious               Boundary", fontsize = "x-large")
plt.ylabel("Absolute difference\n between true time and perceived time", fontsize = "x-large")
plt.yticks(fontsize = "x-large")
plt.axhline(y = 0.0, color = 'k', linestyle = '-')
plt.title("All participants (N = %s) duration bias"%totalpts, fontsize = "x-large")
#plt.legend(handles=legend_elements, loc='center')
ax.xaxis.set_tick_params(labelbottom=False)
ax.set_xticks([])
# Out:
# []

# %% [markdown]
# ### above should work for R

# %%
#sub = np.repeat(sub, len(pt.condition))
cb_df= pd.DataFrame({"pt": sub,
            "rho": rho_ls, 
            "zscr":zscr_ls, 
            "condition":cond_ls, 
            "timepoint":tp_ls, 
            "response":resp_ls,
            "resp_diff": resp_diff_ls})
cb_df.to_csv('/Users/ayesh/Desktop/Gradstuff/duration_judgement/summary/mturk_summary/cb_dfr.csv')

# %%
boundary = []
continious = []
catch = []
summary_files
# Out:
# ['A1153ZIEQX0ZJ8.csv',
#  'A14W0AXTJ3R19V.csv',
#  'A183WYXN12P2TJ.csv',
#  'A1P6OXEJ86HQRM.csv',
#  'A1YC558J4E5KZ.csv',
#  'A1YTNGH5SMM2CJ.csv',
#  'A1ZD9SJXQ9C6EW.csv',
#  'A207IHY6GERCFO.csv',
#  'A22KRF782ELLB0.csv',
#  'A26UIS59SY4NM6.csv',
#  'A27W025UEXS1G0.csv',
#  'A2EI075XZT9Y2S.csv',
#  'A2HOUSKURBF8UA.csv',
#  'A2MCG5W6LHSRG9.csv',
#  'A2S7ZT3VZBU2UA.csv',
#  'A2VC1UC5Q0E9PO.csv',
#  'A2VLTSW6CXIUMR.csv',
#  'A30RAYNDOWQ61S.csv',
#  'A3DW6KSQPG6GVQ.csv',
#  'A3G55RJTW3BSGM.csv',
#  'A3GK90X2QOFR53.csv',
#  'A3HPLIWSXW3XV8.csv',
#  'A3KP8KFGG6734Q.csv',
#  'A3O81LHBBI8NPK.csv',
#  'A3RLCGRXA34GC0.csv',
#  'A3UV55HC87DO9C.csv',
#  'A6JKKANO7F4KD.csv',
#  'AA9V4NE8SOA4I.csv',
#  'AGVUHOBSCP6YC.csv',
#  'ANVAFB99K5RKP.csv',
#  'AOAZMLP27GD81.csv',
#  'AOIR8V07FYMH5.csv',
#  'APGX2WZ59OWDN.csv',
#  'AR1IWBDA7MC86.csv',
#  'AUI3R928P63B0.csv',
#  'AUQTHU5AOZVQC.csv',
#  'AVPKE76DJLWK6.csv',
#  'color.csv',
#  'Greg.csv']

# %%
grp_csv = pd.read_csv('/Users/ayesh/Desktop/Gradstuff/duration_judgement/summary/mturk_summary/cb_dfr.csv')
grp_csv_cln = grp_csv[grp_csv.rho>= 0.75]
grp_csv_cln
#cond_ls = grp_csv_cln.condition
#tp_ls = grp_csv_cln.timepoint
#resp_ls = grp_csv_cln.response
#resp_diff_ls = grp_csv_cln.resp_diff
# Out:
#     Unnamed: 0              pt       rho      zscr  \
# 1            1  A14W0AXTJ3R19V  0.849396  1.253980
# 2            2  A183WYXN12P2TJ  0.933431  1.684409
# 3            3  A1P6OXEJ86HQRM  0.921616  1.599648
# 4            4   A1YC558J4E5KZ  0.846458  1.243526
# 5            5  A1YTNGH5SMM2CJ  0.971831  2.124249
# 6            6  A1ZD9SJXQ9C6EW  0.881948  1.384470
# 7            7  A207IHY6GERCFO  0.890673  1.425171
# 8            8  A22KRF782ELLB0  0.932003  1.673423
# 9            9  A26UIS59SY4NM6  0.916707  1.568002
# 10          10  A27W025UEXS1G0  0.941016  1.746853
# 11          11  A2EI075XZT9Y2S  0.927088  1.637253
# 12          12  A2HOUSKURBF8UA  0.907553  1.513472
# 13          13  A2MCG5W6LHSRG9  0.918088  1.576722
# 14          14  A2S7ZT3VZBU2UA  0.874044  1.349960
# 15          15  A2VC1UC5Q0E9PO  0.903700  1.492042
# 16          16  A2VLTSW6CXIUMR  0.932590  1.677915
# 17          17  A30RAYNDOWQ61S  0.917691  1.574201
# 18          18  A3DW6KSQPG6GVQ  0.844467  1.236543
# 19          19  A3G55RJTW3BSGM  0.822888  1.165696
# 20          20  A3GK90X2QOFR53  0.815933  1.144529
# 22          22  A3KP8KFGG6734Q  0.950104  1.832845
# 23          23  A3O81LHBBI8NPK  0.773571  1.029158
# 24          24  A3RLCGRXA34GC0  0.959650  1.941469
# 25          25  A3UV55HC87DO9C  0.945235  1.785047
# 26          26   A6JKKANO7F4KD  0.949568  1.827369
# 27          27   AA9V4NE8SOA4I  0.905265  1.500644
# 28          28   AGVUHOBSCP6YC  0.928873  1.650112
# 29          29   ANVAFB99K5RKP  0.944228  1.775676
# 30          30   AOAZMLP27GD81  0.940981  1.746542
# 31          31   AOIR8V07FYMH5  0.848265  1.249934
# 32          32   APGX2WZ59OWDN  0.935019  1.696887
# 33          33   AR1IWBDA7MC86  0.930195  1.659836
# 34          34   AUI3R928P63B0  0.856279  1.279227
# 35          35   AUQTHU5AOZVQC  0.824944  1.172099
# 36          36   AVPKE76DJLWK6  0.923525  1.612473
# 39          39           color  0.946156  1.793763
#
#                                             condition  \
# 1   24    continious\n25    continious\n26      bo...
# 2   24    continious\n25    continious\n26      bo...
# 3   24         catch\n25    continious\n26    cont...
# 4   24    continious\n25      boundary\n26      bo...
# 5   24      boundary\n25    continious\n26      bo...
# 6   24      boundary\n25      boundary\n26      bo...
# 7   24    continious\n25    continious\n26    cont...
# 8   24    continious\n25      boundary\n26    cont...
# 9   24      boundary\n25      boundary\n26    cont...
# 10  24      boundary\n25    continious\n26      bo...
# 11  24    continious\n25         catch\n26    cont...
# 12  24         catch\n25    continious\n26        ...
# 13  24      boundary\n25         catch\n26    cont...
# 14  24      boundary\n25    continious\n26      bo...
# 15  24         catch\n25      boundary\n26    cont...
# 16  24      boundary\n25         catch\n26      bo...
# 17  24    continious\n25    continious\n26      bo...
# 18  24    continious\n25    continious\n26    cont...
# 19  24      boundary\n25      boundary\n26        ...
# 20  24    continious\n25    continious\n26      bo...
# 22  24    continious\n25      boundary\n26      bo...
# 23  24      boundary\n25         catch\n26      bo...
# 24  24    continious\n25    continious\n26    cont...
# 25  24    continious\n25      boundary\n26    cont...
# 26  24    continious\n25         catch\n26    cont...
# 27  24    continious\n25      boundary\n26      bo...
# 28  24    continious\n25    continious\n26    cont...
# 29  24      boundary\n25    continious\n26        ...
# 30  24    continious\n25         catch\n26      bo...
# 31  24      boundary\n25      boundary\n26    cont...
# 32  24    continious\n25    continious\n26      bo...
# 33  24      boundary\n25      boundary\n26      bo...
# 34  24    continious\n25      boundary\n26    cont...
# 35  24    continious\n25    continious\n26    cont...
# 36  24      boundary\n25    continious\n26    cont...
# 39  24    continious\n25      boundary\n26      bo...
#
#                                             timepoint  \
# 1   24    4.5\n25    1.0\n26    4.0\n27    2.0\n28...
# 2   24    3.0\n25    2.5\n26    3.5\n27    3.0\n28...
# 3   24    2.0\n25    0.5\n26    1.0\n27    0.5\n28...
# 4   24    3.0\n25    4.5\n26    3.0\n27    5.0\n28...
# 5   24    3.5\n25    3.0\n26    4.5\n27    1.0\n28...
# 6   24    4.5\n25    3.5\n26    0.5\n27    3.5\n28...
# 7   24    2.5\n25    1.5\n26    2.0\n27    0.5\n28...
# 8   24    0.5\n25    3.0\n26    3.5\n27    4.5\n28...
# 9   24    5.0\n25    3.0\n26    0.5\n27    2.5\n28...
# 10  24    4.5\n25    4.0\n26    3.0\n27    0.5\n28...
# 11  24    4.5\n25    2.0\n26    4.0\n27    1.0\n28...
# 12  24    1.0\n25    2.0\n26    2.5\n27    2.5\n28...
# 13  24    3.5\n25    2.0\n26    1.0\n27    3.5\n28...
# 14  24    1.5\n25    2.0\n26    3.0\n27    5.0\n28...
# 15  24    3.5\n25    2.5\n26    0.5\n27    3.0\n28...
# 16  24    4.5\n25    2.5\n26    0.5\n27    2.0\n28...
# 17  24    2.5\n25    4.0\n26    0.5\n27    4.0\n28...
# 18  24    1.5\n25    5.0\n26    1.5\n27    3.0\n28...
# 19  24    4.0\n25    3.0\n26    2.0\n27    3.0\n28...
# 20  24    0.5\n25    3.5\n26    1.0\n27    5.0\n28...
# 22  24    1.0\n25    3.0\n26    3.0\n27    0.5\n28...
# 23  24    4.5\n25    1.0\n26    2.5\n27    4.0\n28...
# 24  24    2.5\n25    4.0\n26    0.5\n27    3.5\n28...
# 25  24    4.5\n25    1.0\n26    2.0\n27    3.0\n28...
# 26  24    2.5\n25    2.0\n26    3.0\n27    1.5\n28...
# 27  24    4.5\n25    3.0\n26    4.5\n27    1.0\n28...
# 28  24    2.0\n25    1.5\n26    4.5\n27    5.0\n28...
# 29  24    4.0\n25    1.5\n26    1.5\n27    3.5\n28...
# 30  24    2.5\n25    1.0\n26    1.0\n27    2.0\n28...
# 31  24    4.5\n25    3.5\n26    1.5\n27    2.0\n28...
# 32  24    1.5\n25    4.5\n26    1.5\n27    0.5\n28...
# 33  24    1.5\n25    3.0\n26    0.5\n27    2.5\n28...
# 34  24    1.5\n25    4.0\n26    1.0\n27    2.5\n28...
# 35  24    0.5\n25    2.5\n26    1.5\n27    2.0\n28...
# 36  24    5.0\n25    1.5\n26    3.0\n27    0.5\n28...
# 39  24    3.0\n25    3.5\n26    5.0\n27    5.0\n28...
#
#                                              response  \
# 1   24    4.960595\n25    0.683012\n26    3.988616...
# 2   24    2.231481\n25    2.351852\n26    2.800926...
# 3   24    1.035587\n25    0.257961\n26    0.433852...
# 4   24    2.310185\n25    3.879630\n26    2.629630...
# 5   24    4.981482\n25    4.000001\n26    4.972223...
# 6   24    3.982535\n25    2.977726\n26    0.499987...
# 7   24    1.967593\n25    1.000000\n26    1.944444...
# 8   24    0.800000\n25    3.628571\n26    4.661905...
# 9   24    4.462963\n25    1.981481\n26    0.509259...
# 10  24    4.986111\n25    4.481481\n26    3.990741...
# 11  24    2.979167\n25    1.000000\n26    2.500000...
# 12  24    0.507110\n25    1.009135\n26    1.012092...
# 13  24    2.465278\n25    1.000000\n26    0.493056...
# 14  24    1.796296\n25    2.162037\n26    2.976852...
# 15  24    2.986111\n25    2.500000\n26    0.490741...
# 16  24    4.930556\n25    2.995371\n26    0.666667...
# 17  24    2.428911\n25    2.984363\n26    0.695899...
# 18  24    1.985677\n25    4.746094\n26    1.894531...
# 19  24    4.486111\n25    3.490741\n26    1.500000...
# 20  24    0.648972\n25    4.045689\n26    0.845006...
# 22  24    0.897670\n25    2.031551\n26    2.525213...
# 23  24    1.981481\n25    0.967593\n26    0.981481...
# 24  24    3.172222\n25    4.366667\n26    0.838889...
# 25  24    4.492969\n25    1.506250\n26    1.732465...
# 26  24    1.990967\n25    0.977530\n26    2.995149...
# 27  24    4.976852\n25    3.481481\n26    4.023148...
# 28  24    1.518519\n25    0.509259\n26    3.995370...
# 29  24    4.899023\n25    1.001733\n26    1.496387...
# 30  24    2.486111\n25    0.981481\n26    0.495370...
# 31  24    4.949074\n25    4.097222\n26    1.898148...
# 32  24    1.476852\n25    4.000000\n26    1.000000...
# 33  24    1.295830\n25    2.327868\n26    0.916336...
# 34  24    2.004630\n25    3.990741\n26    1.986111...
# 35  24    0.116612\n25    2.398049\n26    0.427458...
# 36  24    4.513889\n25    1.504630\n26    2.495371...
# 39  24    1.789596\n25    2.511646\n26    3.528727...
#
#                                             resp_diff
# 1   [-0.4605954470000002, 0.31698774099999993, 0.0...
# 2   [0.7685185190000001, 0.1481481480000002, 0.699...
# 3   [0.9644131549999999, 0.242038947, 0.566147569,...
# 4   [0.6898148150000001, 0.6203703699999998, 0.370...
# 5   [-1.4814816969999995, -1.0000005349999999, -0....
# 6   [0.5174646380000003, 0.5222736389999998, 1.311...
# 7   [0.5324074069999998, 0.4999998940000001, 0.055...
# 8   [-0.30000000000000004, -0.628571429, -1.161904...
# 9   [0.5370370370000002, 1.0185185190000001, -0.00...
# 10  [-0.4861111110000005, -0.4814814810000003, -0....
# 11  [1.5208332269999998, 0.9999998940000001, 1.5, ...
# 12  [0.49288953299999994, 0.990864704, 1.487908209...
# 13  [1.034722222, 0.9999998940000001, 0.506944285,...
# 14  [-0.29629643800000016, -0.16203732000000004, 0...
# 15  [0.513888889, 0.0, 0.009259258999999964, 0.995...
# 16  [-0.43055555599999984, -0.49537058200000006, -...
# 17  [0.071089336, 1.0156367410000002, -0.195899297...
# 18  [-0.4856770830000001, 0.25390625, -0.39453125,...
# 19  [-0.4861111110000005, -0.4907407410000002, 0.5...
# 20  [-0.14897226500000005, -0.5456890539999995, 0....
# 22  [0.10233042999999997, 0.9684492769999999, 0.47...
# 23  [2.518518519, 0.032407407, 1.5185185190000001,...
# 24  [-0.6722221369999999, -0.3666665819999997, -0....
# 25  [0.007031249999999822, -0.5062500000000001, 0....
# 26  [0.5090326490000001, 1.02246967, 0.00485073399...
# 27  [-0.47685185200000024, -0.4814814810000003, 0....
# 28  [0.4814814809999999, 0.990740741, 0.5046296300...
# 29  [-0.8990232469999997, 0.49826667599999985, 0.0...
# 30  [0.01388888899999996, 0.01851851900000001, 0.5...
# 31  [-0.44907407399999943, -0.5972222220000001, -0...
# 32  [0.0231481480000002, 0.5, 0.5, 0.0972222220000...
# 33  [0.20416988699999994, 0.6721320689999999, -0.4...
# 34  [-0.5046296300000002, 0.009259258999999798, -0...
# 35  [0.383388096, 0.10195138199999976, 1.072542436...
# 36  [0.4861111110000005, -0.004629770999999838, 0....
# 39  [1.2104037269999999, 0.9883540369999997, 1.471...

# %%
cond_flat = [item for sublist in cond_ls for item in sublist]
time_flat = [item for sublist in t for item in sublist]
resp_flat = [item for sublist in resp_ls for item in sublist]
resp_diff_flat = [item for sublist in resp_diff_ls for item in sublist]

# %%
cond_flat
# Out:
# ['2',
#  '4',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'c',
#  'o',
#  'n',
#  't',
#  'i',
#  'n',
#  'i',
#  'o',
#  'u',
#  's',
#  '\n',
#  '2',
#  '5',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'c',
#  'o',
#  'n',
#  't',
#  'i',
#  'n',
#  'i',
#  'o',
#  'u',
#  's',
#  '\n',
#  '2',
#  '6',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'b',
#  'o',
#  'u',
#  'n',
#  'd',
#  'a',
#  'r',
#  'y',
#  '\n',
#  '2',
#  '7',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'b',
#  'o',
#  'u',
#  'n',
#  'd',
#  'a',
#  'r',
#  'y',
#  '\n',
#  '2',
#  '8',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'c',
#  'o',
#  'n',
#  't',
#  'i',
#  'n',
#  'i',
#  'o',
#  'u',
#  's',
#  '\n',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '.',
#  '.',
#  '.',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '\n',
#  '8',
#  '5',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'c',
#  'o',
#  'n',
#  't',
#  'i',
#  'n',
#  'i',
#  'o',
#  'u',
#  's',
#  '\n',
#  '8',
#  '6',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'c',
#  'o',
#  'n',
#  't',
#  'i',
#  'n',
#  'i',
#  'o',
#  'u',
#  's',
#  '\n',
#  '8',
#  '7',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'b',
#  'o',
#  'u',
#  'n',
#  'd',
#  'a',
#  'r',
#  'y',
#  '\n',
#  '8',
#  '8',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'b',
#  'o',
#  'u',
#  'n',
#  'd',
#  'a',
#  'r',
#  'y',
#  '\n',
#  '8',
#  '9',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'b',
#  'o',
#  'u',
#  'n',
#  'd',
#  'a',
#  'r',
#  'y',
#  '\n',
#  'N',
#  'a',
#  'm',
#  'e',
#  ':',
#  ' ',
#  'c',
#  'o',
#  'n',
#  'd',
#  'i',
#  't',
#  'i',
#  'o',
#  'n',
#  ',',
#  ' ',
#  'L',
#  'e',
#  'n',
#  'g',
#  't',
#  'h',
#  ':',
#  ' ',
#  '6',
#  '6',
#  ',',
#  ' ',
#  'd',
#  't',
#  'y',
#  'p',
#  'e',
#  ':',
#  ' ',
#  'o',
#  'b',
#  'j',
#  'e',
#  'c',
#  't',
#  '2',
#  '4',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'c',
#  'o',
#  'n',
#  't',
#  'i',
#  'n',
#  'i',
#  'o',
#  'u',
#  's',
#  '\n',
#  '2',
#  '5',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'c',
#  'o',
#  'n',
#  't',
#  'i',
#  'n',
#  'i',
#  'o',
#  'u',
#  's',
#  '\n',
#  '2',
#  '6',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'b',
#  'o',
#  'u',
#  'n',
#  'd',
#  'a',
#  'r',
#  'y',
#  '\n',
#  '2',
#  '7',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'c',
#  'o',
#  'n',
#  't',
#  'i',
#  'n',
#  'i',
#  'o',
#  'u',
#  's',
#  '\n',
#  '2',
#  '8',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'b',
#  'o',
#  'u',
#  'n',
#  'd',
#  'a',
#  'r',
#  'y',
#  '\n',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '.',
#  '.',
#  '.',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '\n',
#  '8',
#  '5',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'c',
#  'o',
#  'n',
#  't',
#  'i',
#  'n',
#  'i',
#  'o',
#  'u',
#  's',
#  '\n',
#  '8',
#  '6',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'b',
#  'o',
#  'u',
#  'n',
#  'd',
#  'a',
#  'r',
#  'y',
#  '\n',
#  '8',
#  '7',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'b',
#  'o',
#  'u',
#  'n',
#  'd',
#  'a',
#  'r',
#  'y',
#  '\n',
#  '8',
#  '8',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'b',
#  'o',
#  'u',
#  'n',
#  'd',
#  'a',
#  'r',
#  'y',
#  '\n',
#  '8',
#  '9',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'b',
#  'o',
#  'u',
#  'n',
#  'd',
#  'a',
#  'r',
#  'y',
#  '\n',
#  'N',
#  'a',
#  'm',
#  'e',
#  ':',
#  ' ',
#  'c',
#  'o',
#  'n',
#  'd',
#  'i',
#  't',
#  'i',
#  'o',
#  'n',
#  ',',
#  ' ',
#  'L',
#  'e',
#  'n',
#  'g',
#  't',
#  'h',
#  ':',
#  ' ',
#  '6',
#  '6',
#  ',',
#  ' ',
#  'd',
#  't',
#  'y',
#  'p',
#  'e',
#  ':',
#  ' ',
#  'o',
#  'b',
#  'j',
#  'e',
#  'c',
#  't',
#  '2',
#  '4',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'c',
#  'a',
#  't',
#  'c',
#  'h',
#  '\n',
#  '2',
#  '5',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'c',
#  'o',
#  'n',
#  't',
#  'i',
#  'n',
#  'i',
#  'o',
#  'u',
#  's',
#  '\n',
#  '2',
#  '6',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'c',
#  'o',
#  'n',
#  't',
#  'i',
#  'n',
#  'i',
#  'o',
#  'u',
#  's',
#  '\n',
#  '2',
#  '7',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'b',
#  'o',
#  'u',
#  'n',
#  'd',
#  'a',
#  'r',
#  'y',
#  '\n',
#  '2',
#  '8',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'b',
#  'o',
#  'u',
#  'n',
#  'd',
#  'a',
#  'r',
#  'y',
#  '\n',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '.',
#  '.',
#  '.',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '\n',
#  '8',
#  '5',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'c',
#  'o',
#  'n',
#  't',
#  'i',
#  'n',
#  'i',
#  'o',
#  'u',
#  's',
#  '\n',
#  '8',
#  '6',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'b',
#  'o',
#  'u',
#  'n',
#  'd',
#  'a',
#  'r',
#  'y',
#  '\n',
#  '8',
#  '7',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'b',
#  'o',
#  'u',
#  'n',
#  'd',
#  'a',
#  'r',
#  'y',
#  '\n',
#  '8',
#  '8',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'c',
#  'a',
#  't',
#  'c',
#  'h',
#  '\n',
#  '8',
#  '9',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'c',
#  'o',
#  'n',
#  't',
#  'i',
#  'n',
#  'i',
#  'o',
#  'u',
#  's',
#  '\n',
#  'N',
#  'a',
#  'm',
#  'e',
#  ':',
#  ' ',
#  'c',
#  'o',
#  'n',
#  'd',
#  'i',
#  't',
#  'i',
#  'o',
#  'n',
#  ',',
#  ' ',
#  'L',
#  'e',
#  'n',
#  'g',
#  't',
#  'h',
#  ':',
#  ' ',
#  '6',
#  '6',
#  ',',
#  ' ',
#  'd',
#  't',
#  'y',
#  'p',
#  'e',
#  ':',
#  ' ',
#  'o',
#  'b',
#  'j',
#  'e',
#  'c',
#  't',
#  '2',
#  '4',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'c',
#  'o',
#  'n',
#  't',
#  'i',
#  'n',
#  'i',
#  'o',
#  'u',
#  's',
#  '\n',
#  '2',
#  '5',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'b',
#  'o',
#  'u',
#  'n',
#  'd',
#  'a',
#  'r',
#  'y',
#  '\n',
#  '2',
#  '6',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'b',
#  'o',
#  'u',
#  'n',
#  'd',
#  'a',
#  'r',
#  'y',
#  '\n',
#  '2',
#  '7',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'b',
#  'o',
#  'u',
#  'n',
#  'd',
#  'a',
#  'r',
#  'y',
#  '\n',
#  '2',
#  '8',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'c',
#  'o',
#  'n',
#  't',
#  'i',
#  'n',
#  'i',
#  'o',
#  'u',
#  's',
#  '\n',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '.',
#  '.',
#  '.',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '\n',
#  '8',
#  '5',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'c',
#  'o',
#  'n',
#  't',
#  'i',
#  'n',
#  'i',
#  'o',
#  'u',
#  's',
#  '\n',
#  '8',
#  '6',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'b',
#  'o',
#  'u',
#  'n',
#  'd',
#  'a',
#  'r',
#  'y',
#  '\n',
#  '8',
#  '7',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'c',
#  'o',
#  'n',
#  't',
#  'i',
#  'n',
#  'i',
#  'o',
#  'u',
#  's',
#  '\n',
#  '8',
#  '8',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'c',
#  'o',
#  'n',
#  't',
#  'i',
#  'n',
#  'i',
#  'o',
#  'u',
#  's',
#  '\n',
#  '8',
#  '9',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'c',
#  'o',
#  'n',
#  't',
#  'i',
#  'n',
#  'i',
#  'o',
#  'u',
#  's',
#  '\n',
#  'N',
#  'a',
#  'm',
#  'e',
#  ':',
#  ' ',
#  'c',
#  'o',
#  'n',
#  'd',
#  'i',
#  't',
#  'i',
#  'o',
#  'n',
#  ',',
#  ' ',
#  'L',
#  'e',
#  'n',
#  'g',
#  't',
#  'h',
#  ':',
#  ' ',
#  '6',
#  '6',
#  ',',
#  ' ',
#  'd',
#  't',
#  'y',
#  'p',
#  'e',
#  ':',
#  ' ',
#  'o',
#  'b',
#  'j',
#  'e',
#  'c',
#  't',
#  '2',
#  '4',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'b',
#  'o',
#  'u',
#  'n',
#  'd',
#  'a',
#  'r',
#  'y',
#  '\n',
#  '2',
#  '5',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'c',
#  'o',
#  'n',
#  't',
#  'i',
#  'n',
#  'i',
#  'o',
#  'u',
#  's',
#  '\n',
#  '2',
#  '6',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'b',
#  'o',
#  'u',
#  'n',
#  'd',
#  'a',
#  'r',
#  'y',
#  '\n',
#  '2',
#  '7',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'c',
#  'o',
#  'n',
#  't',
#  'i',
#  'n',
#  'i',
#  'o',
#  'u',
#  's',
#  '\n',
#  '2',
#  '8',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'c',
#  'a',
#  't',
#  'c',
#  'h',
#  ...]

# %%
sub_ls = np.repeat(sub, len(pt))
rhos = np.repeat(rho_ls, len(pt))
zscrs = np.repeat(zscr_ls, len(pt))

# %%
len(time_flat)
# Out:
# 5292

# %%
all_pts = pd.DataFrame({"participant": sub_ls, 
                        "rhos": rhos,
                        "zscrs": zscrs,
                        "condition":cond_flat, 
                        "timepoint":time_flat, 
                        "response":resp_flat,
                        "resp_diff": resp_diff_flat})
all_pts

#all_pts_melt = pd.melt(grp_csv_cln, id_vars=['participant'], value_vars=['conts_resp', 'bdry_resp'], var_name='condition', value_name='resp')
#melted_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-105-651cb464d260> in <module>
#       1 #sub = np.repeat(sub, len(pt.condition))
# ----> 2 all_pts = pd.DataFrame({"participant": sub_ls,
#       3                         "rhos": rhos,
#       4                         "zscrs": zscrs,
#       5                         "condition":cond_flat,
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     466
#     467         elif isinstance(data, dict):
# --> 468             mgr = init_dict(data, index, columns, dtype=dtype)
#     469         elif isinstance(data, ma.MaskedArray):
#     470             import numpy.ma.mrecords as mrecords
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     281             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     282         ]
# --> 283     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     284
#     285
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity)
#      76         # figure out the index, if necessary
#      77         if index is None:
# ---> 78             index = extract_index(arrays)
#      79         else:
#      80             index = ensure_index(index)
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in extract_index(data)
#     395             lengths = list(set(raw_lengths))
#     396             if len(lengths) > 1:
# --> 397                 raise ValueError("arrays must all be same length")
#     398
#     399             if have_dicts:
#
# ValueError: arrays must all be same length

# %%
len(resp_diff_ls)
# Out:
# 36

# %%
all_pts_melt.to_csv('/Users/ayesh/Desktop/Gradstuff/duration_judgement/summary/mturk_summary/m_allpts.csv')

# %%
cond_ls
# Out:
# [24    continious
#  25    continious
#  26      boundary
#  27    continious
#  28    continious
#           ...
#  85    continious
#  86    continious
#  87    continious
#  88      boundary
#  89    continious
#  Name: condition, Length: 66, dtype: object,
#  24    continious
#  25    continious
#  26      boundary
#  27      boundary
#  28    continious
#           ...
#  85    continious
#  86    continious
#  87      boundary
#  88      boundary
#  89      boundary
#  Name: condition, Length: 66, dtype: object,
#  24    continious
#  25    continious
#  26      boundary
#  27    continious
#  28      boundary
#           ...
#  85    continious
#  86      boundary
#  87      boundary
#  88      boundary
#  89      boundary
#  Name: condition, Length: 66, dtype: object,
#  24         catch
#  25    continious
#  26    continious
#  27      boundary
#  28      boundary
#           ...
#  85    continious
#  86      boundary
#  87      boundary
#  88         catch
#  89    continious
#  Name: condition, Length: 66, dtype: object,
#  24    continious
#  25      boundary
#  26      boundary
#  27      boundary
#  28    continious
#           ...
#  85    continious
#  86      boundary
#  87    continious
#  88    continious
#  89    continious
#  Name: condition, Length: 66, dtype: object,
#  24      boundary
#  25    continious
#  26      boundary
#  27    continious
#  28         catch
#           ...
#  85      boundary
#  86    continious
#  87         catch
#  88    continious
#  89    continious
#  Name: condition, Length: 66, dtype: object,
#  24      boundary
#  25      boundary
#  26      boundary
#  27    continious
#  28    continious
#           ...
#  85    continious
#  86      boundary
#  87    continious
#  88    continious
#  89      boundary
#  Name: condition, Length: 66, dtype: object,
#  24    continious
#  25    continious
#  26    continious
#  27      boundary
#  28    continious
#           ...
#  85    continious
#  86      boundary
#  87         catch
#  88    continious
#  89      boundary
#  Name: condition, Length: 66, dtype: object,
#  24    continious
#  25      boundary
#  26    continious
#  27    continious
#  28    continious
#           ...
#  85         catch
#  86      boundary
#  87      boundary
#  88    continious
#  89    continious
#  Name: condition, Length: 66, dtype: object,
#  24      boundary
#  25      boundary
#  26    continious
#  27      boundary
#  28    continious
#           ...
#  85    continious
#  86    continious
#  87    continious
#  88    continious
#  89      boundary
#  Name: condition, Length: 66, dtype: object,
#  24      boundary
#  25    continious
#  26      boundary
#  27    continious
#  28      boundary
#           ...
#  85    continious
#  86      boundary
#  87      boundary
#  88    continious
#  89      boundary
#  Name: condition, Length: 66, dtype: object,
#  24    continious
#  25         catch
#  26    continious
#  27    continious
#  28      boundary
#           ...
#  85      boundary
#  86    continious
#  87      boundary
#  88      boundary
#  89      boundary
#  Name: condition, Length: 66, dtype: object,
#  24         catch
#  25    continious
#  26         catch
#  27    continious
#  28      boundary
#           ...
#  85    continious
#  86      boundary
#  87    continious
#  88         catch
#  89      boundary
#  Name: condition, Length: 66, dtype: object,
#  24      boundary
#  25         catch
#  26    continious
#  27    continious
#  28         catch
#           ...
#  85      boundary
#  86    continious
#  87    continious
#  88    continious
#  89    continious
#  Name: condition, Length: 66, dtype: object,
#  24      boundary
#  25    continious
#  26      boundary
#  27      boundary
#  28    continious
#           ...
#  85    continious
#  86      boundary
#  87    continious
#  88      boundary
#  89    continious
#  Name: condition, Length: 66, dtype: object,
#  24         catch
#  25      boundary
#  26    continious
#  27      boundary
#  28    continious
#           ...
#  85    continious
#  86      boundary
#  87      boundary
#  88         catch
#  89         catch
#  Name: condition, Length: 66, dtype: object,
#  24      boundary
#  25         catch
#  26      boundary
#  27      boundary
#  28    continious
#           ...
#  85    continious
#  86    continious
#  87    continious
#  88      boundary
#  89      boundary
#  Name: condition, Length: 66, dtype: object,
#  24    continious
#  25    continious
#  26      boundary
#  27      boundary
#  28    continious
#           ...
#  85    continious
#  86         catch
#  87    continious
#  88      boundary
#  89    continious
#  Name: condition, Length: 66, dtype: object,
#  24    continious
#  25    continious
#  26    continious
#  27    continious
#  28      boundary
#           ...
#  85    continious
#  86      boundary
#  87    continious
#  88    continious
#  89      boundary
#  Name: condition, Length: 66, dtype: object,
#  24      boundary
#  25      boundary
#  26         catch
#  27      boundary
#  28    continious
#           ...
#  85      boundary
#  86      boundary
#  87      boundary
#  88         catch
#  89      boundary
#  Name: condition, Length: 66, dtype: object,
#  24    continious
#  25    continious
#  26      boundary
#  27      boundary
#  28      boundary
#           ...
#  85      boundary
#  86    continious
#  87      boundary
#  88    continious
#  89      boundary
#  Name: condition, Length: 66, dtype: object,
#  24    continious
#  25      boundary
#  26    continious
#  27      boundary
#  28      boundary
#           ...
#  85      boundary
#  86    continious
#  87    continious
#  88    continious
#  89      boundary
#  Name: condition, Length: 66, dtype: object,
#  24    continious
#  25      boundary
#  26      boundary
#  27    continious
#  28    continious
#           ...
#  85      boundary
#  86      boundary
#  87         catch
#  88    continious
#  89      boundary
#  Name: condition, Length: 66, dtype: object,
#  24      boundary
#  25         catch
#  26      boundary
#  27      boundary
#  28    continious
#           ...
#  85    continious
#  86    continious
#  87      boundary
#  88    continious
#  89    continious
#  Name: condition, Length: 66, dtype: object,
#  24    continious
#  25    continious
#  26    continious
#  27      boundary
#  28    continious
#           ...
#  85      boundary
#  86    continious
#  87      boundary
#  88      boundary
#  89      boundary
#  Name: condition, Length: 66, dtype: object,
#  24    continious
#  25      boundary
#  26    continious
#  27    continious
#  28    continious
#           ...
#  85      boundary
#  86    continious
#  87      boundary
#  88      boundary
#  89      boundary
#  Name: condition, Length: 66, dtype: object,
#  24    continious
#  25         catch
#  26    continious
#  27      boundary
#  28    continious
#           ...
#  85    continious
#  86      boundary
#  87      boundary
#  88      boundary
#  89    continious
#  Name: condition, Length: 66, dtype: object,
#  24    continious
#  25      boundary
#  26      boundary
#  27    continious
#  28      boundary
#           ...
#  85      boundary
#  86      boundary
#  87      boundary
#  88      boundary
#  89    continious
#  Name: condition, Length: 66, dtype: object,
#  24    continious
#  25    continious
#  26    continious
#  27      boundary
#  28    continious
#           ...
#  85    continious
#  86    continious
#  87      boundary
#  88      boundary
#  89    continious
#  Name: condition, Length: 66, dtype: object,
#  24      boundary
#  25    continious
#  26         catch
#  27    continious
#  28    continious
#           ...
#  85    continious
#  86      boundary
#  87      boundary
#  88    continious
#  89      boundary
#  Name: condition, Length: 66, dtype: object,
#  24    continious
#  25         catch
#  26      boundary
#  27    continious
#  28    continious
#           ...
#  85         catch
#  86    continious
#  87    continious
#  88      boundary
#  89      boundary
#  Name: condition, Length: 66, dtype: object,
#  24      boundary
#  25      boundary
#  26    continious
#  27      boundary
#  28    continious
#           ...
#  85      boundary
#  86      boundary
#  87    continious
#  88    continious
#  89    continious
#  Name: condition, Length: 66, dtype: object,
#  24    continious
#  25    continious
#  26      boundary
#  27      boundary
#  28         catch
#           ...
#  85    continious
#  86      boundary
#  87      boundary
#  88      boundary
#  89    continious
#  Name: condition, Length: 66, dtype: object,
#  24      boundary
#  25      boundary
#  26      boundary
#  27      boundary
#  28      boundary
#           ...
#  85    continious
#  86    continious
#  87      boundary
#  88    continious
#  89    continious
#  Name: condition, Length: 66, dtype: object,
#  24    continious
#  25      boundary
#  26    continious
#  27    continious
#  28         catch
#           ...
#  85    continious
#  86      boundary
#  87      boundary
#  88    continious
#  89    continious
#  Name: condition, Length: 66, dtype: object,
#  24    continious
#  25    continious
#  26    continious
#  27      boundary
#  28    continious
#           ...
#  85    continious
#  86    continious
#  87    continious
#  88    continious
#  89      boundary
#  Name: condition, Length: 66, dtype: object,
#  24      boundary
#  25    continious
#  26    continious
#  27      boundary
#  28      boundary
#           ...
#  85      boundary
#  86      boundary
#  87         catch
#  88    continious
#  89    continious
#  Name: condition, Length: 66, dtype: object,
#  24      boundary
#  25      boundary
#  26    continious
#  27         catch
#  28    continious
#           ...
#  85    continious
#  86      boundary
#  87         catch
#  88    continious
#  89    continious
#  Name: condition, Length: 66, dtype: object,
#  24    continious
#  25      boundary
#  26    continious
#  27      boundary
#  28    continious
#           ...
#  85      boundary
#  86         catch
#  87      boundary
#  88      boundary
#  89    continious
#  Name: condition, Length: 66, dtype: object,
#  24    continious
#  25      boundary
#  26      boundary
#  27    continious
#  28         catch
#           ...
#  85      boundary
#  86    continious
#  87      boundary
#  88      boundary
#  89    continious
#  Name: condition, Length: 66, dtype: object,
#  24    continious
#  25      boundary
#  26      boundary
#  27    continious
#  28      boundary
#           ...
#  85      boundary
#  86    continious
#  87      boundary
#  88      boundary
#  89    continious
#  Name: condition, Length: 66, dtype: object]

# %%
dof = len(tst_ls[1][-1])-2  # len(x) == len(y)
dist = stats.t(df=dof)
t_vals = np.linspace(-5, 5, 100)
pdf = dist.pdf(t_vals)
fig, ax = plt.subplots(figsize=(8, 5))
def plot(ax):  # we'll re-use this
    ax.plot(t_vals, pdf)
    ax.set_title("Spearman's Rho Test Null Distribution")
    ax.set_xlabel("statistic")
    ax.set_ylabel("probability density")
plot(ax)
plt.show()

# %%
#2 rho values Fisher-transformed; should be significantly above 0 at the group level; i think sooo
##Group level zscore rho
grp_z = np.mean(allz)
print(grp_z)

#for one in pt_files:
fig, ax = plt.subplots(figsize=(8, 5))
plot(ax)
rs = tst_ls[2][2]  # original statistic
transformed = rs * np.sqrt(dof / ((rs+1.0)*(1.0-rs)))
pvalue = dist.cdf(-transformed) + dist.sf(transformed)
annotation = (f'p-value={pvalue:.4f}\n(shaded area)')
props = dict(facecolor='black', width=1, headwidth=5, headlength=8)
_ = ax.annotate(annotation, (2.7, 0.025), (3, 0.03), arrowprops=props)
i = t_vals >= transformed
ax.fill_between(t_vals[i], y1=0, y2=pdf[i], color='C0')
i = t_vals <= -transformed
ax.fill_between(t_vals[i], y1=0, y2=pdf[i], color='C0')
ax.set_xlim(-5, 5)
ax.set_ylim(0, 0.1)
plt.show()
# Out:
# 1.414890503536984
# <ipython-input-9-09b073529ee7>:10: RuntimeWarning: invalid value encountered in sqrt
#   transformed = rs * np.sqrt(dof / ((rs+1.0)*(1.0-rs)))
# C:\Users\ayesh\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1847: RuntimeWarning: invalid value encountered in greater_equal
#   cond2 = (x >= np.asarray(_b)) & cond0
# C:\Users\ayesh\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1932: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= _a)
# <ipython-input-9-09b073529ee7>:15: RuntimeWarning: invalid value encountered in greater_equal
#   i = t_vals >= transformed
# <ipython-input-9-09b073529ee7>:17: RuntimeWarning: invalid value encountered in less_equal
#   i = t_vals <= -transformed

# %% [markdown]
# ## checking individual files:

# %%
ex = pt_files[-2]

allz = []
conds_diff = []
c_len = []
b_len = []
pt_c = []
pt_b = []
sub = []
pt_throwout = []
pto = pd.read_csv(data_dir+ex, header =0)
pto.columns = pto.columns.str.replace(".", "_")
sub_num = ex.split('_', 1)[0]
pt = pto[24:-1]
df = pt[pt['slider_response'].notna()]
tp = df.dur
cond = df.condition
resp = df.slider_response
rho, p = spearmanr(tp, resp)
zscr = np.arctanh(rho)
pt["rho"] = rho
pt["p_value"] = p
pt["zscr"] = zscr
allz.append(zscr)
boundary = []
continious = []
catch = []
sub.append(sub_num)
for index, row in df.iterrows():
    if pt.condition[index] == 'continious':
        continious.append(df.slider_response[index])
        pt_c.append(df.slider_response[index])
    if pt.condition[index] == 'boundary':
        boundary.append(df.slider_response[index])
        pt_b.append(df.slider_response[index])
    if pt.condition[index] == 'catch':
        catch.append(df.slider_response[index])
        pt_throwout.append(df.slider_response[index])
diff = [a - b for a, b in zip(boundary, continious)]

c_len.append(continious)
b_len.append(boundary)
pt["conds_diff"] = np.mean(diff)
tst = [ex, rho, zscr, np.mean(diff), continious, boundary] # add pt.slider_response for checking the below comparison with null dist
tst_ls.append(tst)
# Out:
# <ipython-input-6-184f774aac22>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pt["rho"] = rho
# <ipython-input-6-184f774aac22>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pt["p_value"] = p
# <ipython-input-6-184f774aac22>:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pt["zscr"] = zscr
# <ipython-input-6-184f774aac22>:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pt["conds_diff"] = np.mean(diff)

# %%
g = resp[:-1]
tp2 = tp[:-1]
rho, p = spearmanr(tp, resp)
rho2, p2 = spearmanr(tp2, g)

# %%
tst
# Out:
# ['color_task_2023-11-25_11h05.36.115.csv',
#  0.12822295183524413,
#  0.1289326761780503,
#  -0.07682291656666669,
#  [2.962239583,
#   3.951822917,
#   3.932291667,
#   2.493489583,
#   3.463541667,
#   2.994791667,
#   3.802083333,
#   1.9921875,
#   3.873697917,
#   1.5950520830000001,
#   1.9856770830000001,
#   2.955729167,
#   3.489583333,
#   1.953125,
#   2.864583333,
#   3.9453125,
#   2.994791667,
#   2.102864583,
#   2.473958333,
#   2.942708333,
#   2.5390625,
#   3.33984375,
#   2.6953125,
#   2.688802083,
#   3.235677083,
#   3.880208333,
#   2.513020833,
#   3.37890625,
#   3.37890625,
#   2.044270833],
#  [1.97265625,
#   2.16796875,
#   4.010416667,
#   3.430989583,
#   2.98828125,
#   2.4609375,
#   3.014322917,
#   1.4453125,
#   2.98828125,
#   1.4973958330000001,
#   1.9986979169999999,
#   2.83203125,
#   2.838541667,
#   2.174479167,
#   4.08203125,
#   3.834635417,
#   3.938802083,
#   3.06640625,
#   4.0625,
#   2.024739583,
#   3.463541667,
#   2.571614583,
#   2.63671875,
#   2.467447917,
#   3.020833333,
#   2.98828125,
#   3.977864583,
#   2.239583333,
#   2.623697917,
#   3.33984375]]
