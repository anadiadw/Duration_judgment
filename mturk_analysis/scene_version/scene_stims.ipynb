# %%
## importing all libraries and dependencies
import pandas as pd
import numpy as np
import os
from os import listdir
import glob
from os.path import isfile, join
import shutil
import PIL
from PIL import Image
import random
from random import sample
import math
from heapq import merge
from random import *
import secrets
from scipy.stats import spearmanr
from scipy import stats
import matplotlib.pyplot as plt

# %%
scenes_ls = []
stim_dir = '/Users/ayesh/Desktop/Gradstuff/duration_judgement/cat_scene/scenes/'
scenes = [f for f in listdir(stim_dir)]
for c in scenes:
    scenes_ls.append('scenes/'+ c)
scenes_ls
# Out:
# ['scenes/catch',
#  'scenes/practice',
#  'scenes/scene_003.jpg',
#  'scenes/scene_004.jpg',
#  'scenes/scene_005.jpg',
#  'scenes/scene_006.jpg',
#  'scenes/scene_007.jpg',
#  'scenes/scene_008.jpg',
#  'scenes/scene_009.jpg',
#  'scenes/scene_010.jpg',
#  'scenes/scene_011.jpg',
#  'scenes/scene_014.jpg',
#  'scenes/scene_015.jpg',
#  'scenes/scene_016.jpg',
#  'scenes/scene_017.jpg',
#  'scenes/scene_018.jpeg',
#  'scenes/scene_019.jpg',
#  'scenes/scene_020.jpg',
#  'scenes/scene_021.jpg',
#  'scenes/scene_022.jpg',
#  'scenes/scene_024.jpg',
#  'scenes/scene_025.jpg',
#  'scenes/scene_026.jpg',
#  'scenes/scene_027.jpeg',
#  'scenes/scene_028.jpg',
#  'scenes/scene_029.jpg',
#  'scenes/scene_030.jpg',
#  'scenes/scene_031.jpeg',
#  'scenes/scene_031.jpg',
#  'scenes/scene_032.jpg',
#  'scenes/scene_033.jpeg',
#  'scenes/scene_034.jpeg',
#  'scenes/scene_035.jpg',
#  'scenes/scene_036.jpg',
#  'scenes/scene_037.jpeg',
#  'scenes/scene_038.jpg',
#  'scenes/scene_041.jpeg',
#  'scenes/scene_042.jpg',
#  'scenes/scene_043.jpg',
#  'scenes/scene_044.jpeg',
#  'scenes/scene_045.jpg',
#  'scenes/scene_046.jpg',
#  'scenes/scene_047.jpg',
#  'scenes/scene_048.jpg',
#  'scenes/scene_049.jpg',
#  'scenes/scene_050.jpeg',
#  'scenes/scene_051.jpg',
#  'scenes/scene_052.jpg',
#  'scenes/scene_053.jpeg',
#  'scenes/scene_054.jpg',
#  'scenes/scene_055.jpg',
#  'scenes/scene_056.jpg',
#  'scenes/scene_057.jpeg',
#  'scenes/scene_058.jpg',
#  'scenes/scene_059.jpg',
#  'scenes/scene_060.jpg',
#  'scenes/scene_061.jpeg',
#  'scenes/scene_062.jpg',
#  'scenes/scene_063.jpeg',
#  'scenes/scene_064.jpg',
#  'scenes/scene_065.jpg',
#  'scenes/scene_066.jpg',
#  'scenes/scene_067.jpg',
#  'scenes/scene_068.jpg',
#  'scenes/scene_069.jpeg',
#  'scenes/scene_071.jpg',
#  'scenes/scene_073.jpg',
#  'scenes/scene_074.jpg',
#  'scenes/scene_075.jpg',
#  'scenes/scene_076.jpg',
#  'scenes/scene_077.jpeg',
#  'scenes/scene_078.jpeg',
#  'scenes/scene_079.jpg',
#  'scenes/scene_080.jpeg',
#  'scenes/scene_081.jpeg',
#  'scenes/scene_082.jpg',
#  'scenes/scene_083.jpg',
#  'scenes/scene_084.jpg',
#  'scenes/scene_085.jpg',
#  'scenes/scene_086.jpg',
#  'scenes/scene_087.jpg',
#  'scenes/scene_088.jpg',
#  'scenes/scene_089.jpg',
#  'scenes/scene_090.jpg',
#  'scenes/scene_091.jpg',
#  'scenes/scene_092.jpeg',
#  'scenes/scene_093.jpeg',
#  'scenes/scene_094.jpg',
#  'scenes/scene_095.jpeg',
#  'scenes/scene_097.jpeg',
#  'scenes/scene_098.jpeg',
#  'scenes/scene_099.jpg',
#  'scenes/scene_c1.jpg',
#  'scenes/scene_c2.jpg',
#  'scenes/scene_c3.jpg',
#  'scenes/scene_c4.jpg',
#  'scenes/scene_c5.jpg',
#  'scenes/scene_c6.jpg',
#  'scenes/scene_c7.jpg',
#  'scenes/scene_c8.jpg',
#  'scenes/scene_c9.jpg',
#  'scenes/scene_p1.jpg',
#  'scenes/scene_p10.jpg',
#  'scenes/scene_p11.jpg',
#  'scenes/scene_p12.jpg',
#  'scenes/scene_p2.jpg',
#  'scenes/scene_p3.jpg',
#  'scenes/scene_p4.jpg',
#  'scenes/scene_p5.jpg',
#  'scenes/scene_p6.jpg',
#  'scenes/scene_p7.jpg',
#  'scenes/scene_p8.jpg',
#  'scenes/scene_p9.jpg']
