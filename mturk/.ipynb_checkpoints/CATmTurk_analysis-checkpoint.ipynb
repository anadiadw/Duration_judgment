# %%
## importing all libraries and dependencies
import pandas as pd
import numpy as np
import os
from os import listdir
import glob
from os.path import isfile, join
import shutil
import PIL
from PIL import Image
import random
from random import sample
import math
from heapq import merge
from random import *
import secrets
from scipy.stats import spearmanr
from scipy import stats
import matplotlib.pyplot as plt

# %%
pt_files = []
tst_ls = []
data_dir = '/Users/ayesh/Desktop/Gradstuff/duration_judgement/mTurk_OGdata/data/actual_raw/worth/'
pt_files_ls = [f for f in listdir(data_dir)]
for c in pt_files_ls:
    if c[-3:] == 'csv':
        pt_files.append(c)

# %%
#1,Spearman rank correlation btwn actual duration of trial and the participants resp
### should be positive-- check!!!


#3 permutation test for each participant: over 10,000 iteration
### each participant's full distribution of resp shuffled, 
### rank correlation btwn time of each trial and shuffled resp computed
### Significance higher than 95% of this null distribution
allz = []
conds_diff = []
c_len = []
b_len = []
a_len = []
t_len = []
pt_c = []
pt_b = []
pt_resp = []
pt_cond = []
sub = []
true_tp = []
pt_throwout = []

tst_ls =[]
one_ls =[]
rho_ls =[]
zscr_ls =[]
cond_ls =[]
tp_ls =[]
resp_ls =[]
resp_diff_ls = []

for one in pt_files:
    pto = pd.read_csv(data_dir+one, header =0)
    pto.columns = pto.columns.str.replace(".", "_")
    sub_num = one.split('_', 1)[0]
    pt1 = pto[24:-1]
    pt = pt1[pt1['slider_response'].notna()]
    tp = pt.dur
    cond = pt.condition
    resp = pt.slider_response
    rho, p = spearmanr(tp, resp)
    zscr = np.arctanh(rho)
    pt["rho"] = rho
    pt["p_value"] = p
    pt["zscr"] = zscr
    allz.append(zscr)
    sub.append(sub_num)
    #for index, row in pt.iterrows():
     #   pt_resp.append(pt.slider_response[index])
      #  pt_cond.append(pt.condition[index])
       # true_tp.append(pt.dur[index])
    
    diff = [a - b for a, b in zip(tp, resp)]
    
    #c_len.append(continious)
    #b_len.append(boundary)
    a_len.append(pt_resp)
    t_len.append(true_tp)
    pt["resp_diff"] = (diff)
    #pt["pt_condition"] = pt_cond
    #pt["true_tp"] = true_tp
    #pt["pt_resp"] = pt_resp
    tst = [one, rho, zscr, cond, tp, resp]#np.mean(diff), continious, boundary] # add pt.slider_response for checking the below comparison with null dist
    tst_ls.append(tst)
    one_ls.append(one)
    rho_ls.append(rho)
    zscr_ls.append(zscr)
    cond_ls.append(cond)
    tp_ls.append(tp)
    resp_ls.append(resp)
    resp_diff_ls.append(diff)
    pt.to_csv('/Users/ayesh/Desktop/Gradstuff/duration_judgement/summary/mturk_summary/pt_summaries/' + sub_num + '.csv')
# Out:
# <ipython-input-3-19d704d05188>:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pt["rho"] = rho
# <ipython-input-3-19d704d05188>:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pt["p_value"] = p
# <ipython-input-3-19d704d05188>:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pt["zscr"] = zscr
# <ipython-input-3-19d704d05188>:59: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pt["resp_diff"] = (diff)

# %%
summary_dir = '/Users/ayesh/Desktop/Gradstuff/duration_judgement/summary/mturk_summary/pt_summaries/'
summary_files = [f for f in listdir(summary_dir)]
#cnct_summarydf = pd.DataFrame(columns = ['participant', 'dur', 'condition', 'slider_response', 'rho', 'p_value', 'zscr', 'resp_diff'])
pts = []
boundary = []
continious = []
catch = []
b_mean = []
c_mean = []
ctch_mean = []
for a in summary_files:
    c_trials = []
    b_trials = []
    ctch_trials = []
    m_cont = []
    m_bdry = []
    m_ctch = []
    onept = pd.read_csv(summary_dir + a)
    for index, row in onept.iterrows():
        if onept['condition'][index] == "continious":
            c_trials.append(onept.resp_diff[index])
            m_cont.append(onept.slider_response[index])
        if onept.condition[index] == "boundary":
            b_trials.append(onept.resp_diff[index])
            m_bdry.append(onept.slider_response[index])
        if onept.condition[index] == "catch":
            ctch_trials.append(onept.resp_diff[index])
            m_ctch.append(onept.slider_response[index])
    c_trials = [c_trials for c_trials in c_trials if str(c_trials) != 'nan']
    b_trials = [b_trials for b_trials in b_trials if str(b_trials) != 'nan']
    ctch_trials = [ctch_trials for ctch_trials in ctch_trials if str(ctch_trials) != 'nan']
    
    m_cont = [m_cont for m_cont in m_cont if str(m_cont) != 'nan']
    m_bdry = [m_bdry for m_bdry in m_bdry if str(m_bdry) != 'nan']
    m_ctch = [m_ctch for m_ctch in m_ctch if str(m_ctch) != 'nan']
    
    pts.append(a)
    continious.append(np.mean(c_trials))
    boundary.append(np.mean(b_trials))
    catch.append(np.mean(ctch_trials))
    
    c_mean.append(np.mean(m_cont))
    b_mean.append(np.mean(m_bdry))
    ctch_mean.append(np.mean(m_ctch))
        #onept.participant.astype(str)
        
        #shrt_pt = onept[["participant", 'dur', 'condition', 'slider_response', 'rho', 'p_value', 'zscr', 'resp_diff']]

# %%
len(ctch_mean)
# Out:
# 40

# %%
f_df = pd.DataFrame({"participants":pts,
                    "continious": continious,
                    "boundary":boundary,
                    "catch":catch,
                    "cont_mean": c_mean,
                    "bdry_mean": b_mean,
                    "ctch_mean": ctch_mean})
f_df.to_csv('/Users/ayesh/Desktop/Gradstuff/duration_judgement/summary/mturk_summary/conddurs_r.csv')

# %%
for a in summary_files:
    onept = pd.read_csv(summary_dir + a)
    if onept["rho"][3] < 0.75:
        print (a)
# Out:
# A1153ZIEQX0ZJ8.csv
# A3HPLIWSXW3XV8.csv
# Greg.csv

# %% [markdown]
# ### above should work for R

# %%
#sub = np.repeat(sub, len(pt.condition))
cb_df= pd.DataFrame({"pt": sub,
            "rho": rho_ls, 
            "zscr":zscr_ls, 
            "condition":cond_ls, 
            "timepoint":tp_ls, 
            "response":resp_ls,
            "resp_diff": resp_diff_ls})
cb_df.to_csv('/Users/ayesh/Desktop/Gradstuff/duration_judgement/summary/mturk_summary/cb_dfr.csv')

# %% [markdown]
# ## graph

# %%
grph_csv = pd.read_csv('/Users/ayesh/Desktop/Gradstuff/duration_judgement/summary/mturk_summary/conddurs_r.csv')
grph_csv["abs_continious"] = [abs(t) for t in grph_csv.continious]
grph_csv["abs_boundary"] = [abs(t) for t in grph_csv.boundary]
grph_csv
# Out:
#     Unnamed: 0        participants  continious  boundary     catch  cont_mean  \
# 0            1  A14W0AXTJ3R19V.csv    0.254670 -0.073701  0.802685   2.495330
# 1            2  A183WYXN12P2TJ.csv    0.679630  0.657253  0.243827   2.070370
# 2            3  A1P6OXEJ86HQRM.csv    0.867665  1.201550  0.801636   1.882335
# 3            4   A1YC558J4E5KZ.csv    1.154167  0.842901  1.374228   1.595833
# 4            5  A1YTNGH5SMM2CJ.csv   -0.277624 -0.277932  0.587191   3.027624
# 5            6  A1ZD9SJXQ9C6EW.csv    0.388035  0.388785  1.638092   2.361965
# 6            7  A207IHY6GERCFO.csv    0.562346  0.763117  0.442901   2.187654
# 7            8  A22KRF782ELLB0.csv   -0.094286  0.370000  0.323016   2.844286
# 8            9  A26UIS59SY4NM6.csv    0.338272  0.833642  1.257716   2.411728
# 9           10  A27W025UEXS1G0.csv    0.160725  0.238349  0.560185   2.589275
# 10          11  A2EI075XZT9Y2S.csv    1.159954  1.425694  1.073495   1.590046
# 11          12  A2HOUSKURBF8UA.csv    0.929180  0.856654  0.914736   1.820820
# 12          13  A2MCG5W6LHSRG9.csv    1.079977  1.150347  1.399306   1.670023
# 13          14  A2S7ZT3VZBU2UA.csv    0.762654  0.780710  0.597222   1.987346
# 14          15  A2VC1UC5Q0E9PO.csv    0.202932  0.452932  0.918210   2.547068
# 15          16  A2VLTSW6CXIUMR.csv   -0.001389 -0.122840 -0.034722   2.751389
# 16          17  A30RAYNDOWQ61S.csv    0.334605  0.587706  0.400689   2.415395
# 17          18  A3DW6KSQPG6GVQ.csv   -0.189019  0.089844  0.450087   2.939019
# 18          19  A3G55RJTW3BSGM.csv    0.864043  0.806790  1.199846   1.885957
# 19          20  A3GK90X2QOFR53.csv    0.635372  1.447960  0.334271   2.114628
# 20          22  A3KP8KFGG6734Q.csv   -0.185649 -0.269049 -0.073108   2.935649
# 21          23  A3O81LHBBI8NPK.csv    0.203395  1.416049 -0.345679   2.546605
# 22          24  A3RLCGRXA34GC0.csv    0.120185  0.227593 -0.029630   2.629815
# 23          25  A3UV55HC87DO9C.csv    0.320333  0.427969  0.213317   2.429667
# 24          26   A6JKKANO7F4KD.csv    0.526420  0.765203  0.689359   2.223580
# 25          27   AA9V4NE8SOA4I.csv    1.002160  1.111574  1.358796   1.747840
# 26          28   AGVUHOBSCP6YC.csv    1.096605  1.099846  0.831019   1.653395
# 27          29   ANVAFB99K5RKP.csv    0.256043  0.326198  0.280477   2.493957
# 28          30   AOAZMLP27GD81.csv    0.199846  0.468673  0.035494   2.550154
# 29          31   AOIR8V07FYMH5.csv   -0.149846  0.212654 -0.098765   2.899846
# 30          32   APGX2WZ59OWDN.csv    0.255864  0.578704  0.655093   2.494136
# 31          33   AR1IWBDA7MC86.csv    0.123320  0.477051 -0.337776   2.626680
# 32          34   AUI3R928P63B0.csv   -0.276389 -0.396605 -0.076389   3.026389
# 33          35   AUQTHU5AOZVQC.csv    1.141329  1.173459  0.687684   1.608671
# 34          36   AVPKE76DJLWK6.csv    0.495370  0.381636  0.537037   2.254630
# 35          38          color1.csv    0.757246  0.881988  0.914079   1.992754
#
#     bdry_mean  ctch_mean  abs_continious  abs_boundary
# 0    2.823701   1.697315        0.254670      0.073701
# 1    2.092747   1.756173        0.679630      0.657253
# 2    1.548450   1.198364        0.867665      1.201550
# 3    1.907099   0.625772        1.154167      0.842901
# 4    3.027932   1.412809        0.277624      0.277932
# 5    2.361215   0.695241        0.388035      0.388785
# 6    1.986883   2.057099        0.562346      0.763117
# 7    2.380000   1.343651        0.094286      0.370000
# 8    1.916358   1.742284        0.338272      0.833642
# 9    2.511651   2.106481        0.160725      0.238349
# 10   1.324306   0.926505        1.159954      1.425694
# 11   1.893346   1.418597        0.929180      0.856654
# 12   1.599653   1.100694        1.079977      1.150347
# 13   1.969290   1.402778        0.762654      0.780710
# 14   2.297068   1.415123        0.202932      0.452932
# 15   2.872840   2.034722        0.001389      0.122840
# 16   2.162294   2.265978        0.334605      0.587706
# 17   2.660156   2.549913        0.189019      0.089844
# 18   1.943210   1.466821        0.864043      0.806790
# 19   1.302040   1.665729        0.635372      1.447960
# 20   3.019049   2.406442        0.185649      0.269049
# 21   1.333951   2.512346        0.203395      1.416049
# 22   2.522407   2.529630        0.120185      0.227593
# 23   2.322031   1.953349        0.320333      0.427969
# 24   1.984797   1.477307        0.526420      0.765203
# 25   1.638426   1.141204        1.002160      1.111574
# 26   1.650154   1.168981        1.096605      1.099846
# 27   2.423802   1.219523        0.256043      0.326198
# 28   2.281327   1.464506        0.199846      0.468673
# 29   2.537346   2.265432        0.149846      0.212654
# 30   2.171296   1.844907        0.255864      0.578704
# 31   2.272949   2.671109        0.123320      0.477051
# 32   3.146605   2.576389        0.276389      0.396605
# 33   1.576541   1.645650        1.141329      1.173459
# 34   2.368364   1.129630        0.495370      0.381636
# 35   1.868012   2.085921        0.757246      0.881988

# %%
mediumseagreen = '#FFB6C1'
cyan = '#DA70D6'
totalpts = len(grph_csv)
fig, ax = plt.subplots(figsize=(5, 6))

##################
#BAR GRAPHS
##################
## necessary variables
ind = np.arange(1) # the x locations for the groups
width = 0.35 # the width of the bars
#source-corrected bias bars
ax.bar(ind, np.mean(grph_csv.continious), width,
    color= mediumseagreen,
    #hatch = '.',
    edgecolor= mediumseagreen,
    alpha = 0.5,
    yerr=stats.sem(grph_csv.continious),
    label = "Safe",
    error_kw=dict(elinewidth=2,ecolor= "black"))
ax.bar(ind+width,np.mean(grph_csv.boundary)  , width,
    color= cyan,
    #hatch = '.',
    edgecolor= cyan,
    alpha = 0.8,
    yerr=stats.sem(grph_csv.boundary),
    label = "Threat",
    error_kw=dict(elinewidth=2,ecolor= "black"))

#ax.legend()

##################
#SCATTERPLOT GRAPHS
##################
exps2 = []
#i = 1.0
i = 0.2

     # Get the values for same_context and bound_context bias in each valence condition
h = grph_csv.continious
d = grph_csv.boundary
     # Set up the x-axis values
x1 = i - 0.2
x2 = i + 0.2
line_color = ["black"]
line_colors = np.repeat(line_color, len(d))
alphas = [0.5]*len(line_colors)

     # Plot the lines connecting the dots
for hi, di, ci, ai in zip(h, d, line_colors, alphas):
    ax.plot([x1 + 0.03, x2 - 0.08], [hi, di], c=ci, alpha=ai, linewidth = 1)

        # Plot the points
        # Note: s=25 increase the default point size, lw=0.5 decreases the default point line width
ax.scatter(len(h)*[x1+0.03], h, c=mediumseagreen, edgecolors= "black",
s=25, lw=0.5, zorder=10)
ax.scatter(len(d)*[x2-0.08], d, c=cyan, edgecolors= "black",
s=25, lw=0.5, zorder=10)
#ax.legend(loc = 'lower left', fontsize = "large")

# Fix the axes and labels 
#legend_elements = []
plt.ylim(-1, 2)
plt.xlabel("Continious               Boundary", fontsize = "x-large")
plt.ylabel("True time- perceived time", fontsize = "x-large")
plt.yticks(fontsize = "x-large")
plt.axhline(y = 0.0, color = 'k', linestyle = '-')
plt.title("All participants (N = %s) duration bias"%totalpts, fontsize = "x-large")
#plt.legend(handles=legend_elements, loc='center')
ax.xaxis.set_tick_params(labelbottom=False)
ax.set_xticks([])
# Out:
# []

# %%
mediumseagreen = '#FFB6C1'
cyan = '#DA70D6'
totalpts = len(grph_csv)
fig, ax = plt.subplots(figsize=(5, 6))

##################
#BAR GRAPHS
##################
## necessary variables
ind = np.arange(1) # the x locations for the groups
width = 0.35 # the width of the bars
#source-corrected bias bars
ax.bar(ind, np.mean(grph_csv.abs_continious), width,
    color= mediumseagreen,
    #hatch = '.',
    edgecolor= mediumseagreen,
    alpha = 0.5,
    yerr=stats.sem(grph_csv.abs_continious),
    label = "Safe",
    error_kw=dict(elinewidth=2,ecolor= "black"))
ax.bar(ind+width,np.mean(grph_csv.abs_boundary)  , width,
    color= cyan,
    #hatch = '.',
    edgecolor= cyan,
    alpha = 0.8,
    yerr=stats.sem(grph_csv.abs_boundary),
    label = "Threat",
    error_kw=dict(elinewidth=2,ecolor= "black"))

#ax.legend()

##################
#SCATTERPLOT GRAPHS
##################
exps2 = []
#i = 1.0
i = 0.2

     # Get the values for same_context and bound_context bias in each valence condition
h = grph_csv.abs_continious
d = grph_csv.abs_boundary
     # Set up the x-axis values
x1 = i - 0.2
x2 = i + 0.2
line_color = ["black"]
line_colors = np.repeat(line_color, len(d))
alphas = [0.5]*len(line_colors)

     # Plot the lines connecting the dots
for hi, di, ci, ai in zip(h, d, line_colors, alphas):
    ax.plot([x1 + 0.03, x2 - 0.08], [hi, di], c=ci, alpha=ai, linewidth = 1)

        # Plot the points
        # Note: s=25 increase the default point size, lw=0.5 decreases the default point line width
ax.scatter(len(h)*[x1+0.03], h, c=mediumseagreen, edgecolors= "black",
s=25, lw=0.5, zorder=10)
ax.scatter(len(d)*[x2-0.08], d, c=cyan, edgecolors= "black",
s=25, lw=0.5, zorder=10)
#ax.legend(loc = 'lower left', fontsize = "large")

# Fix the axes and labels 
#legend_elements = []
plt.ylim(0, 2)
plt.xlabel("Continious               Boundary", fontsize = "x-large")
plt.ylabel("Absolute difference\n between true time and perceived time", fontsize = "x-large")
plt.yticks(fontsize = "x-large")
plt.axhline(y = 0.0, color = 'k', linestyle = '-')
plt.title("All participants (N = %s) duration bias"%totalpts, fontsize = "x-large")
#plt.legend(handles=legend_elements, loc='center')
ax.xaxis.set_tick_params(labelbottom=False)
ax.set_xticks([])
plt.savefig('CAT_OG.pdf')

# %%
mediumseagreen = '#FFB6C1' #pink
cyan = '#DA70D6' #orchid
totalpts = len(grph_csv)
fig, ax = plt.subplots(figsize=(5, 6))

##################
#BAR GRAPHS
##################
## necessary variables
ind = np.arange(1) # the x locations for the groups
width = 0.35 # the width of the bars
#source-corrected bias bars
ax.bar(ind, np.mean(grph_csv.cont_mean), width,
    color= mediumseagreen,
    #hatch = '.',
    edgecolor= mediumseagreen,
    alpha = 0.5,
    yerr=stats.sem(grph_csv.cont_mean),
    label = "Safe",
    error_kw=dict(elinewidth=2,ecolor= "black"))
ax.bar(ind+width,np.mean(grph_csv.bdry_mean)  , width,
    color= cyan,
    #hatch = '.',
    edgecolor= cyan,
    alpha = 0.8,
    yerr=stats.sem(grph_csv.bdry_mean),
    label = "Threat",
    error_kw=dict(elinewidth=2,ecolor= "black"))

#ax.legend()

##################
#SCATTERPLOT GRAPHS
##################
exps2 = []
#i = 1.0
i = 0.2

     # Get the values for same_context and bound_context bias in each valence condition
h = grph_csv.cont_mean
d = grph_csv.bdry_mean
     # Set up the x-axis values
x1 = i - 0.2
x2 = i + 0.2
line_color = ["black"]
line_colors = np.repeat(line_color, len(d))
alphas = [0.5]*len(line_colors)

     # Plot the lines connecting the dots
for hi, di, ci, ai in zip(h, d, line_colors, alphas):
    ax.plot([x1 + 0.03, x2 - 0.08], [hi, di], c=ci, alpha=ai, linewidth = 1)

        # Plot the points
        # Note: s=25 increase the default point size, lw=0.5 decreases the default point line width
ax.scatter(len(h)*[x1+0.03], h, c=mediumseagreen, edgecolors= "black",
s=25, lw=0.5, zorder=10)
ax.scatter(len(d)*[x2-0.08], d, c=cyan, edgecolors= "black",
s=25, lw=0.5, zorder=10)
#ax.legend(loc = 'lower left', fontsize = "large")

# Fix the axes and labels 
#legend_elements = []
plt.ylim(0, 4)
plt.xlabel("Continious               Boundary", fontsize = "x-large")
plt.ylabel("Mean duration judgement (s)", fontsize = "x-large")
plt.yticks(fontsize = "x-large")
plt.axhline(y = 0.0, color = 'k', linestyle = '-')
plt.title("All participants (N = %s) duration bias"%totalpts, fontsize = "x-large")
#plt.legend(handles=legend_elements, loc='center')
ax.xaxis.set_tick_params(labelbottom=False)
ax.set_xticks([])
# Out:
# []

# %% [markdown]
# ## group check if correlation significant

# %%
#combine all files in the list
combined_csv = pd.concat([pd.read_csv(summary_dir + f) for f in summary_files])
#export to csv
combined_csv.to_csv('/Users/ayesh/Desktop/Gradstuff/duration_judgement/summary/mturk_summary/combined_csv.csv', index=False, encoding='utf-8-sig')
to_cln = pd.read_csv('/Users/ayesh/Desktop/Gradstuff/duration_judgement/summary/mturk_summary/combined_csv.csv') #, index=False, encoding='utf-8-sig')
to_cln
clnd_combined = to_cln[to_cln["rho"]>=0.75]
clnd_combined.to_csv('/Users/ayesh/Desktop/Gradstuff/duration_judgement/summary/mturk_summary/combined_csv.csv', index=False, encoding='utf-8-sig')

# %%
clnd_combined.participant.unique()
# Out:
# array(['A14W0AXTJ3R19V', 'A183WYXN12P2TJ', 'A1P6OXEJ86HQRM',
#        'A1YC558J4E5KZ', 'A1YTNGH5SMM2CJ', 'A1ZD9SJXQ9C6EW',
#        'A207IHY6GERCFO', 'A22KRF782ELLB0', 'A26UIS59SY4NM6',
#        'A27W025UEXS1G0', 'A2EI075XZT9Y2S', 'A2HOUSKURBF8UA',
#        'A2MCG5W6LHSRG9', 'A2S7ZT3VZBU2UA', 'A2VC1UC5Q0E9PO',
#        'A2VLTSW6CXIUMR', 'A30RAYNDOWQ61S', 'A3DW6KSQPG6GVQ',
#        'A3G55RJTW3BSGM', 'A3GK90X2QOFR53', 'A3KP8KFGG6734Q',
#        'A3O81LHBBI8NPK', 'A3RLCGRXA34GC0', 'A3UV55HC87DO9C',
#        'A6JKKANO7F4KD', 'AA9V4NE8SOA4I', 'AGVUHOBSCP6YC', 'ANVAFB99K5RKP',
#        'AOAZMLP27GD81', 'AOIR8V07FYMH5', 'APGX2WZ59OWDN', 'AR1IWBDA7MC86',
#        'AUI3R928P63B0', 'AUQTHU5AOZVQC', 'AVPKE76DJLWK6', 'color1'],
#       dtype=object)

# %%
boundary = []
continious = []
catch = []
summary_files
# Out:
# ['A1153ZIEQX0ZJ8.csv',
#  'A14W0AXTJ3R19V.csv',
#  'A183WYXN12P2TJ.csv',
#  'A1P6OXEJ86HQRM.csv',
#  'A1YC558J4E5KZ.csv',
#  'A1YTNGH5SMM2CJ.csv',
#  'A1ZD9SJXQ9C6EW.csv',
#  'A207IHY6GERCFO.csv',
#  'A22KRF782ELLB0.csv',
#  'A26UIS59SY4NM6.csv',
#  'A27W025UEXS1G0.csv',
#  'A2EI075XZT9Y2S.csv',
#  'A2HOUSKURBF8UA.csv',
#  'A2MCG5W6LHSRG9.csv',
#  'A2S7ZT3VZBU2UA.csv',
#  'A2VC1UC5Q0E9PO.csv',
#  'A2VLTSW6CXIUMR.csv',
#  'A30RAYNDOWQ61S.csv',
#  'A3DW6KSQPG6GVQ.csv',
#  'A3G55RJTW3BSGM.csv',
#  'A3GK90X2QOFR53.csv',
#  'A3HPLIWSXW3XV8.csv',
#  'A3KP8KFGG6734Q.csv',
#  'A3O81LHBBI8NPK.csv',
#  'A3RLCGRXA34GC0.csv',
#  'A3UV55HC87DO9C.csv',
#  'A6JKKANO7F4KD.csv',
#  'AA9V4NE8SOA4I.csv',
#  'AGVUHOBSCP6YC.csv',
#  'ANVAFB99K5RKP.csv',
#  'AOAZMLP27GD81.csv',
#  'AOIR8V07FYMH5.csv',
#  'APGX2WZ59OWDN.csv',
#  'AR1IWBDA7MC86.csv',
#  'AUI3R928P63B0.csv',
#  'AUQTHU5AOZVQC.csv',
#  'AVPKE76DJLWK6.csv',
#  'color.csv',
#  'Greg.csv']

# %%
grp_csv = pd.read_csv('/Users/ayesh/Desktop/Gradstuff/duration_judgement/summary/mturk_summary/cb_dfr.csv')
grp_csv_cln = grp_csv[grp_csv.rho>= 0.75]
grp_csv_cln
#cond_ls = grp_csv_cln.condition
#tp_ls = grp_csv_cln.timepoint
#resp_ls = grp_csv_cln.response
#resp_diff_ls = grp_csv_cln.resp_diff
# Out:
#     Unnamed: 0              pt       rho      zscr  \
# 1            1  A14W0AXTJ3R19V  0.849396  1.253980
# 2            2  A183WYXN12P2TJ  0.933431  1.684409
# 3            3  A1P6OXEJ86HQRM  0.921616  1.599648
# 4            4   A1YC558J4E5KZ  0.846458  1.243526
# 5            5  A1YTNGH5SMM2CJ  0.971831  2.124249
# 6            6  A1ZD9SJXQ9C6EW  0.881948  1.384470
# 7            7  A207IHY6GERCFO  0.890673  1.425171
# 8            8  A22KRF782ELLB0  0.932003  1.673423
# 9            9  A26UIS59SY4NM6  0.916707  1.568002
# 10          10  A27W025UEXS1G0  0.941016  1.746853
# 11          11  A2EI075XZT9Y2S  0.927088  1.637253
# 12          12  A2HOUSKURBF8UA  0.907553  1.513472
# 13          13  A2MCG5W6LHSRG9  0.918088  1.576722
# 14          14  A2S7ZT3VZBU2UA  0.874044  1.349960
# 15          15  A2VC1UC5Q0E9PO  0.903700  1.492042
# 16          16  A2VLTSW6CXIUMR  0.932590  1.677915
# 17          17  A30RAYNDOWQ61S  0.917691  1.574201
# 18          18  A3DW6KSQPG6GVQ  0.844467  1.236543
# 19          19  A3G55RJTW3BSGM  0.822888  1.165696
# 20          20  A3GK90X2QOFR53  0.815933  1.144529
# 22          22  A3KP8KFGG6734Q  0.950104  1.832845
# 23          23  A3O81LHBBI8NPK  0.773571  1.029158
# 24          24  A3RLCGRXA34GC0  0.959650  1.941469
# 25          25  A3UV55HC87DO9C  0.945235  1.785047
# 26          26   A6JKKANO7F4KD  0.949568  1.827369
# 27          27   AA9V4NE8SOA4I  0.905265  1.500644
# 28          28   AGVUHOBSCP6YC  0.928873  1.650112
# 29          29   ANVAFB99K5RKP  0.944228  1.775676
# 30          30   AOAZMLP27GD81  0.940981  1.746542
# 31          31   AOIR8V07FYMH5  0.848265  1.249934
# 32          32   APGX2WZ59OWDN  0.935019  1.696887
# 33          33   AR1IWBDA7MC86  0.930195  1.659836
# 34          34   AUI3R928P63B0  0.856279  1.279227
# 35          35   AUQTHU5AOZVQC  0.824944  1.172099
# 36          36   AVPKE76DJLWK6  0.923525  1.612473
# 39          39           color  0.946156  1.793763
#
#                                             condition  \
# 1   24    continious\n25    continious\n26      bo...
# 2   24    continious\n25    continious\n26      bo...
# 3   24         catch\n25    continious\n26    cont...
# 4   24    continious\n25      boundary\n26      bo...
# 5   24      boundary\n25    continious\n26      bo...
# 6   24      boundary\n25      boundary\n26      bo...
# 7   24    continious\n25    continious\n26    cont...
# 8   24    continious\n25      boundary\n26    cont...
# 9   24      boundary\n25      boundary\n26    cont...
# 10  24      boundary\n25    continious\n26      bo...
# 11  24    continious\n25         catch\n26    cont...
# 12  24         catch\n25    continious\n26        ...
# 13  24      boundary\n25         catch\n26    cont...
# 14  24      boundary\n25    continious\n26      bo...
# 15  24         catch\n25      boundary\n26    cont...
# 16  24      boundary\n25         catch\n26      bo...
# 17  24    continious\n25    continious\n26      bo...
# 18  24    continious\n25    continious\n26    cont...
# 19  24      boundary\n25      boundary\n26        ...
# 20  24    continious\n25    continious\n26      bo...
# 22  24    continious\n25      boundary\n26      bo...
# 23  24      boundary\n25         catch\n26      bo...
# 24  24    continious\n25    continious\n26    cont...
# 25  24    continious\n25      boundary\n26    cont...
# 26  24    continious\n25         catch\n26    cont...
# 27  24    continious\n25      boundary\n26      bo...
# 28  24    continious\n25    continious\n26    cont...
# 29  24      boundary\n25    continious\n26        ...
# 30  24    continious\n25         catch\n26      bo...
# 31  24      boundary\n25      boundary\n26    cont...
# 32  24    continious\n25    continious\n26      bo...
# 33  24      boundary\n25      boundary\n26      bo...
# 34  24    continious\n25      boundary\n26    cont...
# 35  24    continious\n25    continious\n26    cont...
# 36  24      boundary\n25    continious\n26    cont...
# 39  24    continious\n25      boundary\n26      bo...
#
#                                             timepoint  \
# 1   24    4.5\n25    1.0\n26    4.0\n27    2.0\n28...
# 2   24    3.0\n25    2.5\n26    3.5\n27    3.0\n28...
# 3   24    2.0\n25    0.5\n26    1.0\n27    0.5\n28...
# 4   24    3.0\n25    4.5\n26    3.0\n27    5.0\n28...
# 5   24    3.5\n25    3.0\n26    4.5\n27    1.0\n28...
# 6   24    4.5\n25    3.5\n26    0.5\n27    3.5\n28...
# 7   24    2.5\n25    1.5\n26    2.0\n27    0.5\n28...
# 8   24    0.5\n25    3.0\n26    3.5\n27    4.5\n28...
# 9   24    5.0\n25    3.0\n26    0.5\n27    2.5\n28...
# 10  24    4.5\n25    4.0\n26    3.0\n27    0.5\n28...
# 11  24    4.5\n25    2.0\n26    4.0\n27    1.0\n28...
# 12  24    1.0\n25    2.0\n26    2.5\n27    2.5\n28...
# 13  24    3.5\n25    2.0\n26    1.0\n27    3.5\n28...
# 14  24    1.5\n25    2.0\n26    3.0\n27    5.0\n28...
# 15  24    3.5\n25    2.5\n26    0.5\n27    3.0\n28...
# 16  24    4.5\n25    2.5\n26    0.5\n27    2.0\n28...
# 17  24    2.5\n25    4.0\n26    0.5\n27    4.0\n28...
# 18  24    1.5\n25    5.0\n26    1.5\n27    3.0\n28...
# 19  24    4.0\n25    3.0\n26    2.0\n27    3.0\n28...
# 20  24    0.5\n25    3.5\n26    1.0\n27    5.0\n28...
# 22  24    1.0\n25    3.0\n26    3.0\n27    0.5\n28...
# 23  24    4.5\n25    1.0\n26    2.5\n27    4.0\n28...
# 24  24    2.5\n25    4.0\n26    0.5\n27    3.5\n28...
# 25  24    4.5\n25    1.0\n26    2.0\n27    3.0\n28...
# 26  24    2.5\n25    2.0\n26    3.0\n27    1.5\n28...
# 27  24    4.5\n25    3.0\n26    4.5\n27    1.0\n28...
# 28  24    2.0\n25    1.5\n26    4.5\n27    5.0\n28...
# 29  24    4.0\n25    1.5\n26    1.5\n27    3.5\n28...
# 30  24    2.5\n25    1.0\n26    1.0\n27    2.0\n28...
# 31  24    4.5\n25    3.5\n26    1.5\n27    2.0\n28...
# 32  24    1.5\n25    4.5\n26    1.5\n27    0.5\n28...
# 33  24    1.5\n25    3.0\n26    0.5\n27    2.5\n28...
# 34  24    1.5\n25    4.0\n26    1.0\n27    2.5\n28...
# 35  24    0.5\n25    2.5\n26    1.5\n27    2.0\n28...
# 36  24    5.0\n25    1.5\n26    3.0\n27    0.5\n28...
# 39  24    3.0\n25    3.5\n26    5.0\n27    5.0\n28...
#
#                                              response  \
# 1   24    4.960595\n25    0.683012\n26    3.988616...
# 2   24    2.231481\n25    2.351852\n26    2.800926...
# 3   24    1.035587\n25    0.257961\n26    0.433852...
# 4   24    2.310185\n25    3.879630\n26    2.629630...
# 5   24    4.981482\n25    4.000001\n26    4.972223...
# 6   24    3.982535\n25    2.977726\n26    0.499987...
# 7   24    1.967593\n25    1.000000\n26    1.944444...
# 8   24    0.800000\n25    3.628571\n26    4.661905...
# 9   24    4.462963\n25    1.981481\n26    0.509259...
# 10  24    4.986111\n25    4.481481\n26    3.990741...
# 11  24    2.979167\n25    1.000000\n26    2.500000...
# 12  24    0.507110\n25    1.009135\n26    1.012092...
# 13  24    2.465278\n25    1.000000\n26    0.493056...
# 14  24    1.796296\n25    2.162037\n26    2.976852...
# 15  24    2.986111\n25    2.500000\n26    0.490741...
# 16  24    4.930556\n25    2.995371\n26    0.666667...
# 17  24    2.428911\n25    2.984363\n26    0.695899...
# 18  24    1.985677\n25    4.746094\n26    1.894531...
# 19  24    4.486111\n25    3.490741\n26    1.500000...
# 20  24    0.648972\n25    4.045689\n26    0.845006...
# 22  24    0.897670\n25    2.031551\n26    2.525213...
# 23  24    1.981481\n25    0.967593\n26    0.981481...
# 24  24    3.172222\n25    4.366667\n26    0.838889...
# 25  24    4.492969\n25    1.506250\n26    1.732465...
# 26  24    1.990967\n25    0.977530\n26    2.995149...
# 27  24    4.976852\n25    3.481481\n26    4.023148...
# 28  24    1.518519\n25    0.509259\n26    3.995370...
# 29  24    4.899023\n25    1.001733\n26    1.496387...
# 30  24    2.486111\n25    0.981481\n26    0.495370...
# 31  24    4.949074\n25    4.097222\n26    1.898148...
# 32  24    1.476852\n25    4.000000\n26    1.000000...
# 33  24    1.295830\n25    2.327868\n26    0.916336...
# 34  24    2.004630\n25    3.990741\n26    1.986111...
# 35  24    0.116612\n25    2.398049\n26    0.427458...
# 36  24    4.513889\n25    1.504630\n26    2.495371...
# 39  24    1.789596\n25    2.511646\n26    3.528727...
#
#                                             resp_diff
# 1   [-0.4605954470000002, 0.31698774099999993, 0.0...
# 2   [0.7685185190000001, 0.1481481480000002, 0.699...
# 3   [0.9644131549999999, 0.242038947, 0.566147569,...
# 4   [0.6898148150000001, 0.6203703699999998, 0.370...
# 5   [-1.4814816969999995, -1.0000005349999999, -0....
# 6   [0.5174646380000003, 0.5222736389999998, 1.311...
# 7   [0.5324074069999998, 0.4999998940000001, 0.055...
# 8   [-0.30000000000000004, -0.628571429, -1.161904...
# 9   [0.5370370370000002, 1.0185185190000001, -0.00...
# 10  [-0.4861111110000005, -0.4814814810000003, -0....
# 11  [1.5208332269999998, 0.9999998940000001, 1.5, ...
# 12  [0.49288953299999994, 0.990864704, 1.487908209...
# 13  [1.034722222, 0.9999998940000001, 0.506944285,...
# 14  [-0.29629643800000016, -0.16203732000000004, 0...
# 15  [0.513888889, 0.0, 0.009259258999999964, 0.995...
# 16  [-0.43055555599999984, -0.49537058200000006, -...
# 17  [0.071089336, 1.0156367410000002, -0.195899297...
# 18  [-0.4856770830000001, 0.25390625, -0.39453125,...
# 19  [-0.4861111110000005, -0.4907407410000002, 0.5...
# 20  [-0.14897226500000005, -0.5456890539999995, 0....
# 22  [0.10233042999999997, 0.9684492769999999, 0.47...
# 23  [2.518518519, 0.032407407, 1.5185185190000001,...
# 24  [-0.6722221369999999, -0.3666665819999997, -0....
# 25  [0.007031249999999822, -0.5062500000000001, 0....
# 26  [0.5090326490000001, 1.02246967, 0.00485073399...
# 27  [-0.47685185200000024, -0.4814814810000003, 0....
# 28  [0.4814814809999999, 0.990740741, 0.5046296300...
# 29  [-0.8990232469999997, 0.49826667599999985, 0.0...
# 30  [0.01388888899999996, 0.01851851900000001, 0.5...
# 31  [-0.44907407399999943, -0.5972222220000001, -0...
# 32  [0.0231481480000002, 0.5, 0.5, 0.0972222220000...
# 33  [0.20416988699999994, 0.6721320689999999, -0.4...
# 34  [-0.5046296300000002, 0.009259258999999798, -0...
# 35  [0.383388096, 0.10195138199999976, 1.072542436...
# 36  [0.4861111110000005, -0.004629770999999838, 0....
# 39  [1.2104037269999999, 0.9883540369999997, 1.471...

# %%
cond_flat = [item for sublist in cond_ls for item in sublist]
time_flat = [item for sublist in t for item in sublist]
resp_flat = [item for sublist in resp_ls for item in sublist]
resp_diff_flat = [item for sublist in resp_diff_ls for item in sublist]

# %%
cond_flat
# Out:
# ['2',
#  '4',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'c',
#  'o',
#  'n',
#  't',
#  'i',
#  'n',
#  'i',
#  'o',
#  'u',
#  's',
#  '\n',
#  '2',
#  '5',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'c',
#  'o',
#  'n',
#  't',
#  'i',
#  'n',
#  'i',
#  'o',
#  'u',
#  's',
#  '\n',
#  '2',
#  '6',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'b',
#  'o',
#  'u',
#  'n',
#  'd',
#  'a',
#  'r',
#  'y',
#  '\n',
#  '2',
#  '7',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'b',
#  'o',
#  'u',
#  'n',
#  'd',
#  'a',
#  'r',
#  'y',
#  '\n',
#  '2',
#  '8',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'c',
#  'o',
#  'n',
#  't',
#  'i',
#  'n',
#  'i',
#  'o',
#  'u',
#  's',
#  '\n',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '.',
#  '.',
#  '.',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '\n',
#  '8',
#  '5',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'c',
#  'o',
#  'n',
#  't',
#  'i',
#  'n',
#  'i',
#  'o',
#  'u',
#  's',
#  '\n',
#  '8',
#  '6',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'c',
#  'o',
#  'n',
#  't',
#  'i',
#  'n',
#  'i',
#  'o',
#  'u',
#  's',
#  '\n',
#  '8',
#  '7',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'b',
#  'o',
#  'u',
#  'n',
#  'd',
#  'a',
#  'r',
#  'y',
#  '\n',
#  '8',
#  '8',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'b',
#  'o',
#  'u',
#  'n',
#  'd',
#  'a',
#  'r',
#  'y',
#  '\n',
#  '8',
#  '9',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'b',
#  'o',
#  'u',
#  'n',
#  'd',
#  'a',
#  'r',
#  'y',
#  '\n',
#  'N',
#  'a',
#  'm',
#  'e',
#  ':',
#  ' ',
#  'c',
#  'o',
#  'n',
#  'd',
#  'i',
#  't',
#  'i',
#  'o',
#  'n',
#  ',',
#  ' ',
#  'L',
#  'e',
#  'n',
#  'g',
#  't',
#  'h',
#  ':',
#  ' ',
#  '6',
#  '6',
#  ',',
#  ' ',
#  'd',
#  't',
#  'y',
#  'p',
#  'e',
#  ':',
#  ' ',
#  'o',
#  'b',
#  'j',
#  'e',
#  'c',
#  't',
#  '2',
#  '4',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'c',
#  'o',
#  'n',
#  't',
#  'i',
#  'n',
#  'i',
#  'o',
#  'u',
#  's',
#  '\n',
#  '2',
#  '5',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'c',
#  'o',
#  'n',
#  't',
#  'i',
#  'n',
#  'i',
#  'o',
#  'u',
#  's',
#  '\n',
#  '2',
#  '6',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'b',
#  'o',
#  'u',
#  'n',
#  'd',
#  'a',
#  'r',
#  'y',
#  '\n',
#  '2',
#  '7',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'c',
#  'o',
#  'n',
#  't',
#  'i',
#  'n',
#  'i',
#  'o',
#  'u',
#  's',
#  '\n',
#  '2',
#  '8',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'b',
#  'o',
#  'u',
#  'n',
#  'd',
#  'a',
#  'r',
#  'y',
#  '\n',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '.',
#  '.',
#  '.',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '\n',
#  '8',
#  '5',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'c',
#  'o',
#  'n',
#  't',
#  'i',
#  'n',
#  'i',
#  'o',
#  'u',
#  's',
#  '\n',
#  '8',
#  '6',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'b',
#  'o',
#  'u',
#  'n',
#  'd',
#  'a',
#  'r',
#  'y',
#  '\n',
#  '8',
#  '7',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'b',
#  'o',
#  'u',
#  'n',
#  'd',
#  'a',
#  'r',
#  'y',
#  '\n',
#  '8',
#  '8',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'b',
#  'o',
#  'u',
#  'n',
#  'd',
#  'a',
#  'r',
#  'y',
#  '\n',
#  '8',
#  '9',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'b',
#  'o',
#  'u',
#  'n',
#  'd',
#  'a',
#  'r',
#  'y',
#  '\n',
#  'N',
#  'a',
#  'm',
#  'e',
#  ':',
#  ' ',
#  'c',
#  'o',
#  'n',
#  'd',
#  'i',
#  't',
#  'i',
#  'o',
#  'n',
#  ',',
#  ' ',
#  'L',
#  'e',
#  'n',
#  'g',
#  't',
#  'h',
#  ':',
#  ' ',
#  '6',
#  '6',
#  ',',
#  ' ',
#  'd',
#  't',
#  'y',
#  'p',
#  'e',
#  ':',
#  ' ',
#  'o',
#  'b',
#  'j',
#  'e',
#  'c',
#  't',
#  '2',
#  '4',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'c',
#  'a',
#  't',
#  'c',
#  'h',
#  '\n',
#  '2',
#  '5',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'c',
#  'o',
#  'n',
#  't',
#  'i',
#  'n',
#  'i',
#  'o',
#  'u',
#  's',
#  '\n',
#  '2',
#  '6',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'c',
#  'o',
#  'n',
#  't',
#  'i',
#  'n',
#  'i',
#  'o',
#  'u',
#  's',
#  '\n',
#  '2',
#  '7',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'b',
#  'o',
#  'u',
#  'n',
#  'd',
#  'a',
#  'r',
#  'y',
#  '\n',
#  '2',
#  '8',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'b',
#  'o',
#  'u',
#  'n',
#  'd',
#  'a',
#  'r',
#  'y',
#  '\n',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '.',
#  '.',
#  '.',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '\n',
#  '8',
#  '5',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'c',
#  'o',
#  'n',
#  't',
#  'i',
#  'n',
#  'i',
#  'o',
#  'u',
#  's',
#  '\n',
#  '8',
#  '6',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'b',
#  'o',
#  'u',
#  'n',
#  'd',
#  'a',
#  'r',
#  'y',
#  '\n',
#  '8',
#  '7',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'b',
#  'o',
#  'u',
#  'n',
#  'd',
#  'a',
#  'r',
#  'y',
#  '\n',
#  '8',
#  '8',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'c',
#  'a',
#  't',
#  'c',
#  'h',
#  '\n',
#  '8',
#  '9',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'c',
#  'o',
#  'n',
#  't',
#  'i',
#  'n',
#  'i',
#  'o',
#  'u',
#  's',
#  '\n',
#  'N',
#  'a',
#  'm',
#  'e',
#  ':',
#  ' ',
#  'c',
#  'o',
#  'n',
#  'd',
#  'i',
#  't',
#  'i',
#  'o',
#  'n',
#  ',',
#  ' ',
#  'L',
#  'e',
#  'n',
#  'g',
#  't',
#  'h',
#  ':',
#  ' ',
#  '6',
#  '6',
#  ',',
#  ' ',
#  'd',
#  't',
#  'y',
#  'p',
#  'e',
#  ':',
#  ' ',
#  'o',
#  'b',
#  'j',
#  'e',
#  'c',
#  't',
#  '2',
#  '4',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'c',
#  'o',
#  'n',
#  't',
#  'i',
#  'n',
#  'i',
#  'o',
#  'u',
#  's',
#  '\n',
#  '2',
#  '5',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'b',
#  'o',
#  'u',
#  'n',
#  'd',
#  'a',
#  'r',
#  'y',
#  '\n',
#  '2',
#  '6',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'b',
#  'o',
#  'u',
#  'n',
#  'd',
#  'a',
#  'r',
#  'y',
#  '\n',
#  '2',
#  '7',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'b',
#  'o',
#  'u',
#  'n',
#  'd',
#  'a',
#  'r',
#  'y',
#  '\n',
#  '2',
#  '8',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'c',
#  'o',
#  'n',
#  't',
#  'i',
#  'n',
#  'i',
#  'o',
#  'u',
#  's',
#  '\n',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '.',
#  '.',
#  '.',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '\n',
#  '8',
#  '5',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'c',
#  'o',
#  'n',
#  't',
#  'i',
#  'n',
#  'i',
#  'o',
#  'u',
#  's',
#  '\n',
#  '8',
#  '6',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'b',
#  'o',
#  'u',
#  'n',
#  'd',
#  'a',
#  'r',
#  'y',
#  '\n',
#  '8',
#  '7',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'c',
#  'o',
#  'n',
#  't',
#  'i',
#  'n',
#  'i',
#  'o',
#  'u',
#  's',
#  '\n',
#  '8',
#  '8',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'c',
#  'o',
#  'n',
#  't',
#  'i',
#  'n',
#  'i',
#  'o',
#  'u',
#  's',
#  '\n',
#  '8',
#  '9',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'c',
#  'o',
#  'n',
#  't',
#  'i',
#  'n',
#  'i',
#  'o',
#  'u',
#  's',
#  '\n',
#  'N',
#  'a',
#  'm',
#  'e',
#  ':',
#  ' ',
#  'c',
#  'o',
#  'n',
#  'd',
#  'i',
#  't',
#  'i',
#  'o',
#  'n',
#  ',',
#  ' ',
#  'L',
#  'e',
#  'n',
#  'g',
#  't',
#  'h',
#  ':',
#  ' ',
#  '6',
#  '6',
#  ',',
#  ' ',
#  'd',
#  't',
#  'y',
#  'p',
#  'e',
#  ':',
#  ' ',
#  'o',
#  'b',
#  'j',
#  'e',
#  'c',
#  't',
#  '2',
#  '4',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'b',
#  'o',
#  'u',
#  'n',
#  'd',
#  'a',
#  'r',
#  'y',
#  '\n',
#  '2',
#  '5',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'c',
#  'o',
#  'n',
#  't',
#  'i',
#  'n',
#  'i',
#  'o',
#  'u',
#  's',
#  '\n',
#  '2',
#  '6',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'b',
#  'o',
#  'u',
#  'n',
#  'd',
#  'a',
#  'r',
#  'y',
#  '\n',
#  '2',
#  '7',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'c',
#  'o',
#  'n',
#  't',
#  'i',
#  'n',
#  'i',
#  'o',
#  'u',
#  's',
#  '\n',
#  '2',
#  '8',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'c',
#  'a',
#  't',
#  'c',
#  'h',
#  ...]

# %%
sub_ls = np.repeat(sub, len(pt))
rhos = np.repeat(rho_ls, len(pt))
zscrs = np.repeat(zscr_ls, len(pt))

# %%
len(time_flat)
# Out:
# 5292

# %%
all_pts = pd.DataFrame({"participant": sub_ls, 
                        "rhos": rhos,
                        "zscrs": zscrs,
                        "condition":cond_flat, 
                        "timepoint":time_flat, 
                        "response":resp_flat,
                        "resp_diff": resp_diff_flat})
all_pts

#all_pts_melt = pd.melt(grp_csv_cln, id_vars=['participant'], value_vars=['conts_resp', 'bdry_resp'], var_name='condition', value_name='resp')
#melted_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-105-651cb464d260> in <module>
#       1 #sub = np.repeat(sub, len(pt.condition))
# ----> 2 all_pts = pd.DataFrame({"participant": sub_ls,
#       3                         "rhos": rhos,
#       4                         "zscrs": zscrs,
#       5                         "condition":cond_flat,
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     466
#     467         elif isinstance(data, dict):
# --> 468             mgr = init_dict(data, index, columns, dtype=dtype)
#     469         elif isinstance(data, ma.MaskedArray):
#     470             import numpy.ma.mrecords as mrecords
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     281             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     282         ]
# --> 283     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     284
#     285
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity)
#      76         # figure out the index, if necessary
#      77         if index is None:
# ---> 78             index = extract_index(arrays)
#      79         else:
#      80             index = ensure_index(index)
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in extract_index(data)
#     395             lengths = list(set(raw_lengths))
#     396             if len(lengths) > 1:
# --> 397                 raise ValueError("arrays must all be same length")
#     398
#     399             if have_dicts:
#
# ValueError: arrays must all be same length

# %%
len(resp_diff_ls)
# Out:
# 36

# %%
all_pts_melt.to_csv('/Users/ayesh/Desktop/Gradstuff/duration_judgement/summary/mturk_summary/m_allpts.csv')

# %%
cond_ls
# Out:
# [24    continious
#  25    continious
#  26      boundary
#  27    continious
#  28    continious
#           ...
#  85    continious
#  86    continious
#  87    continious
#  88      boundary
#  89    continious
#  Name: condition, Length: 66, dtype: object,
#  24    continious
#  25    continious
#  26      boundary
#  27      boundary
#  28    continious
#           ...
#  85    continious
#  86    continious
#  87      boundary
#  88      boundary
#  89      boundary
#  Name: condition, Length: 66, dtype: object,
#  24    continious
#  25    continious
#  26      boundary
#  27    continious
#  28      boundary
#           ...
#  85    continious
#  86      boundary
#  87      boundary
#  88      boundary
#  89      boundary
#  Name: condition, Length: 66, dtype: object,
#  24         catch
#  25    continious
#  26    continious
#  27      boundary
#  28      boundary
#           ...
#  85    continious
#  86      boundary
#  87      boundary
#  88         catch
#  89    continious
#  Name: condition, Length: 66, dtype: object,
#  24    continious
#  25      boundary
#  26      boundary
#  27      boundary
#  28    continious
#           ...
#  85    continious
#  86      boundary
#  87    continious
#  88    continious
#  89    continious
#  Name: condition, Length: 66, dtype: object,
#  24      boundary
#  25    continious
#  26      boundary
#  27    continious
#  28         catch
#           ...
#  85      boundary
#  86    continious
#  87         catch
#  88    continious
#  89    continious
#  Name: condition, Length: 66, dtype: object,
#  24      boundary
#  25      boundary
#  26      boundary
#  27    continious
#  28    continious
#           ...
#  85    continious
#  86      boundary
#  87    continious
#  88    continious
#  89      boundary
#  Name: condition, Length: 66, dtype: object,
#  24    continious
#  25    continious
#  26    continious
#  27      boundary
#  28    continious
#           ...
#  85    continious
#  86      boundary
#  87         catch
#  88    continious
#  89      boundary
#  Name: condition, Length: 66, dtype: object,
#  24    continious
#  25      boundary
#  26    continious
#  27    continious
#  28    continious
#           ...
#  85         catch
#  86      boundary
#  87      boundary
#  88    continious
#  89    continious
#  Name: condition, Length: 66, dtype: object,
#  24      boundary
#  25      boundary
#  26    continious
#  27      boundary
#  28    continious
#           ...
#  85    continious
#  86    continious
#  87    continious
#  88    continious
#  89      boundary
#  Name: condition, Length: 66, dtype: object,
#  24      boundary
#  25    continious
#  26      boundary
#  27    continious
#  28      boundary
#           ...
#  85    continious
#  86      boundary
#  87      boundary
#  88    continious
#  89      boundary
#  Name: condition, Length: 66, dtype: object,
#  24    continious
#  25         catch
#  26    continious
#  27    continious
#  28      boundary
#           ...
#  85      boundary
#  86    continious
#  87      boundary
#  88      boundary
#  89      boundary
#  Name: condition, Length: 66, dtype: object,
#  24         catch
#  25    continious
#  26         catch
#  27    continious
#  28      boundary
#           ...
#  85    continious
#  86      boundary
#  87    continious
#  88         catch
#  89      boundary
#  Name: condition, Length: 66, dtype: object,
#  24      boundary
#  25         catch
#  26    continious
#  27    continious
#  28         catch
#           ...
#  85      boundary
#  86    continious
#  87    continious
#  88    continious
#  89    continious
#  Name: condition, Length: 66, dtype: object,
#  24      boundary
#  25    continious
#  26      boundary
#  27      boundary
#  28    continious
#           ...
#  85    continious
#  86      boundary
#  87    continious
#  88      boundary
#  89    continious
#  Name: condition, Length: 66, dtype: object,
#  24         catch
#  25      boundary
#  26    continious
#  27      boundary
#  28    continious
#           ...
#  85    continious
#  86      boundary
#  87      boundary
#  88         catch
#  89         catch
#  Name: condition, Length: 66, dtype: object,
#  24      boundary
#  25         catch
#  26      boundary
#  27      boundary
#  28    continious
#           ...
#  85    continious
#  86    continious
#  87    continious
#  88      boundary
#  89      boundary
#  Name: condition, Length: 66, dtype: object,
#  24    continious
#  25    continious
#  26      boundary
#  27      boundary
#  28    continious
#           ...
#  85    continious
#  86         catch
#  87    continious
#  88      boundary
#  89    continious
#  Name: condition, Length: 66, dtype: object,
#  24    continious
#  25    continious
#  26    continious
#  27    continious
#  28      boundary
#           ...
#  85    continious
#  86      boundary
#  87    continious
#  88    continious
#  89      boundary
#  Name: condition, Length: 66, dtype: object,
#  24      boundary
#  25      boundary
#  26         catch
#  27      boundary
#  28    continious
#           ...
#  85      boundary
#  86      boundary
#  87      boundary
#  88         catch
#  89      boundary
#  Name: condition, Length: 66, dtype: object,
#  24    continious
#  25    continious
#  26      boundary
#  27      boundary
#  28      boundary
#           ...
#  85      boundary
#  86    continious
#  87      boundary
#  88    continious
#  89      boundary
#  Name: condition, Length: 66, dtype: object,
#  24    continious
#  25      boundary
#  26    continious
#  27      boundary
#  28      boundary
#           ...
#  85      boundary
#  86    continious
#  87    continious
#  88    continious
#  89      boundary
#  Name: condition, Length: 66, dtype: object,
#  24    continious
#  25      boundary
#  26      boundary
#  27    continious
#  28    continious
#           ...
#  85      boundary
#  86      boundary
#  87         catch
#  88    continious
#  89      boundary
#  Name: condition, Length: 66, dtype: object,
#  24      boundary
#  25         catch
#  26      boundary
#  27      boundary
#  28    continious
#           ...
#  85    continious
#  86    continious
#  87      boundary
#  88    continious
#  89    continious
#  Name: condition, Length: 66, dtype: object,
#  24    continious
#  25    continious
#  26    continious
#  27      boundary
#  28    continious
#           ...
#  85      boundary
#  86    continious
#  87      boundary
#  88      boundary
#  89      boundary
#  Name: condition, Length: 66, dtype: object,
#  24    continious
#  25      boundary
#  26    continious
#  27    continious
#  28    continious
#           ...
#  85      boundary
#  86    continious
#  87      boundary
#  88      boundary
#  89      boundary
#  Name: condition, Length: 66, dtype: object,
#  24    continious
#  25         catch
#  26    continious
#  27      boundary
#  28    continious
#           ...
#  85    continious
#  86      boundary
#  87      boundary
#  88      boundary
#  89    continious
#  Name: condition, Length: 66, dtype: object,
#  24    continious
#  25      boundary
#  26      boundary
#  27    continious
#  28      boundary
#           ...
#  85      boundary
#  86      boundary
#  87      boundary
#  88      boundary
#  89    continious
#  Name: condition, Length: 66, dtype: object,
#  24    continious
#  25    continious
#  26    continious
#  27      boundary
#  28    continious
#           ...
#  85    continious
#  86    continious
#  87      boundary
#  88      boundary
#  89    continious
#  Name: condition, Length: 66, dtype: object,
#  24      boundary
#  25    continious
#  26         catch
#  27    continious
#  28    continious
#           ...
#  85    continious
#  86      boundary
#  87      boundary
#  88    continious
#  89      boundary
#  Name: condition, Length: 66, dtype: object,
#  24    continious
#  25         catch
#  26      boundary
#  27    continious
#  28    continious
#           ...
#  85         catch
#  86    continious
#  87    continious
#  88      boundary
#  89      boundary
#  Name: condition, Length: 66, dtype: object,
#  24      boundary
#  25      boundary
#  26    continious
#  27      boundary
#  28    continious
#           ...
#  85      boundary
#  86      boundary
#  87    continious
#  88    continious
#  89    continious
#  Name: condition, Length: 66, dtype: object,
#  24    continious
#  25    continious
#  26      boundary
#  27      boundary
#  28         catch
#           ...
#  85    continious
#  86      boundary
#  87      boundary
#  88      boundary
#  89    continious
#  Name: condition, Length: 66, dtype: object,
#  24      boundary
#  25      boundary
#  26      boundary
#  27      boundary
#  28      boundary
#           ...
#  85    continious
#  86    continious
#  87      boundary
#  88    continious
#  89    continious
#  Name: condition, Length: 66, dtype: object,
#  24    continious
#  25      boundary
#  26    continious
#  27    continious
#  28         catch
#           ...
#  85    continious
#  86      boundary
#  87      boundary
#  88    continious
#  89    continious
#  Name: condition, Length: 66, dtype: object,
#  24    continious
#  25    continious
#  26    continious
#  27      boundary
#  28    continious
#           ...
#  85    continious
#  86    continious
#  87    continious
#  88    continious
#  89      boundary
#  Name: condition, Length: 66, dtype: object,
#  24      boundary
#  25    continious
#  26    continious
#  27      boundary
#  28      boundary
#           ...
#  85      boundary
#  86      boundary
#  87         catch
#  88    continious
#  89    continious
#  Name: condition, Length: 66, dtype: object,
#  24      boundary
#  25      boundary
#  26    continious
#  27         catch
#  28    continious
#           ...
#  85    continious
#  86      boundary
#  87         catch
#  88    continious
#  89    continious
#  Name: condition, Length: 66, dtype: object,
#  24    continious
#  25      boundary
#  26    continious
#  27      boundary
#  28    continious
#           ...
#  85      boundary
#  86         catch
#  87      boundary
#  88      boundary
#  89    continious
#  Name: condition, Length: 66, dtype: object,
#  24    continious
#  25      boundary
#  26      boundary
#  27    continious
#  28         catch
#           ...
#  85      boundary
#  86    continious
#  87      boundary
#  88      boundary
#  89    continious
#  Name: condition, Length: 66, dtype: object,
#  24    continious
#  25      boundary
#  26      boundary
#  27    continious
#  28      boundary
#           ...
#  85      boundary
#  86    continious
#  87      boundary
#  88      boundary
#  89    continious
#  Name: condition, Length: 66, dtype: object]

# %%
dof = len(tst_ls[1][-1])-2  # len(x) == len(y)
dist = stats.t(df=dof)
t_vals = np.linspace(-5, 5, 100)
pdf = dist.pdf(t_vals)
fig, ax = plt.subplots(figsize=(8, 5))
def plot(ax):  # we'll re-use this
    ax.plot(t_vals, pdf)
    ax.set_title("Spearman's Rho Test Null Distribution")
    ax.set_xlabel("statistic")
    ax.set_ylabel("probability density")
plot(ax)
plt.show()

# %%
#2 rho values Fisher-transformed; should be significantly above 0 at the group level; i think sooo
##Group level zscore rho
grp_z = np.mean(allz)
print(grp_z)

#for one in pt_files:
fig, ax = plt.subplots(figsize=(8, 5))
plot(ax)
rs = tst_ls[2][2]  # original statistic
transformed = rs * np.sqrt(dof / ((rs+1.0)*(1.0-rs)))
pvalue = dist.cdf(-transformed) + dist.sf(transformed)
annotation = (f'p-value={pvalue:.4f}\n(shaded area)')
props = dict(facecolor='black', width=1, headwidth=5, headlength=8)
_ = ax.annotate(annotation, (2.7, 0.025), (3, 0.03), arrowprops=props)
i = t_vals >= transformed
ax.fill_between(t_vals[i], y1=0, y2=pdf[i], color='C0')
i = t_vals <= -transformed
ax.fill_between(t_vals[i], y1=0, y2=pdf[i], color='C0')
ax.set_xlim(-5, 5)
ax.set_ylim(0, 0.1)
plt.show()
# Out:
# 1.414890503536984
# <ipython-input-9-09b073529ee7>:10: RuntimeWarning: invalid value encountered in sqrt
#   transformed = rs * np.sqrt(dof / ((rs+1.0)*(1.0-rs)))
# C:\Users\ayesh\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1847: RuntimeWarning: invalid value encountered in greater_equal
#   cond2 = (x >= np.asarray(_b)) & cond0
# C:\Users\ayesh\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1932: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= _a)
# <ipython-input-9-09b073529ee7>:15: RuntimeWarning: invalid value encountered in greater_equal
#   i = t_vals >= transformed
# <ipython-input-9-09b073529ee7>:17: RuntimeWarning: invalid value encountered in less_equal
#   i = t_vals <= -transformed

# %% [markdown]
# ## checking individual files:

# %%
ex = pt_files[-2]

allz = []
conds_diff = []
c_len = []
b_len = []
pt_c = []
pt_b = []
sub = []
pt_throwout = []
pto = pd.read_csv(data_dir+ex, header =0)
pto.columns = pto.columns.str.replace(".", "_")
sub_num = ex.split('_', 1)[0]
pt = pto[24:-1]
df = pt[pt['slider_response'].notna()]
tp = df.dur
cond = df.condition
resp = df.slider_response
rho, p = spearmanr(tp, resp)
zscr = np.arctanh(rho)
pt["rho"] = rho
pt["p_value"] = p
pt["zscr"] = zscr
allz.append(zscr)
boundary = []
continious = []
catch = []
sub.append(sub_num)
for index, row in df.iterrows():
    if pt.condition[index] == 'continious':
        continious.append(df.slider_response[index])
        pt_c.append(df.slider_response[index])
    if pt.condition[index] == 'boundary':
        boundary.append(df.slider_response[index])
        pt_b.append(df.slider_response[index])
    if pt.condition[index] == 'catch':
        catch.append(df.slider_response[index])
        pt_throwout.append(df.slider_response[index])
diff = [a - b for a, b in zip(boundary, continious)]

c_len.append(continious)
b_len.append(boundary)
pt["conds_diff"] = np.mean(diff)
tst = [ex, rho, zscr, np.mean(diff), continious, boundary] # add pt.slider_response for checking the below comparison with null dist
tst_ls.append(tst)
# Out:
# <ipython-input-6-184f774aac22>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pt["rho"] = rho
# <ipython-input-6-184f774aac22>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pt["p_value"] = p
# <ipython-input-6-184f774aac22>:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pt["zscr"] = zscr
# <ipython-input-6-184f774aac22>:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pt["conds_diff"] = np.mean(diff)

# %%
g = resp[:-1]
tp2 = tp[:-1]
rho, p = spearmanr(tp, resp)
rho2, p2 = spearmanr(tp2, g)

# %%
tst
# Out:
# ['color_task_2023-11-25_11h05.36.115.csv',
#  0.12822295183524413,
#  0.1289326761780503,
#  -0.07682291656666669,
#  [2.962239583,
#   3.951822917,
#   3.932291667,
#   2.493489583,
#   3.463541667,
#   2.994791667,
#   3.802083333,
#   1.9921875,
#   3.873697917,
#   1.5950520830000001,
#   1.9856770830000001,
#   2.955729167,
#   3.489583333,
#   1.953125,
#   2.864583333,
#   3.9453125,
#   2.994791667,
#   2.102864583,
#   2.473958333,
#   2.942708333,
#   2.5390625,
#   3.33984375,
#   2.6953125,
#   2.688802083,
#   3.235677083,
#   3.880208333,
#   2.513020833,
#   3.37890625,
#   3.37890625,
#   2.044270833],
#  [1.97265625,
#   2.16796875,
#   4.010416667,
#   3.430989583,
#   2.98828125,
#   2.4609375,
#   3.014322917,
#   1.4453125,
#   2.98828125,
#   1.4973958330000001,
#   1.9986979169999999,
#   2.83203125,
#   2.838541667,
#   2.174479167,
#   4.08203125,
#   3.834635417,
#   3.938802083,
#   3.06640625,
#   4.0625,
#   2.024739583,
#   3.463541667,
#   2.571614583,
#   2.63671875,
#   2.467447917,
#   3.020833333,
#   2.98828125,
#   3.977864583,
#   2.239583333,
#   2.623697917,
#   3.33984375]]
